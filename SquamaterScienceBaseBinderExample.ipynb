# %% [markdown]
# # <img align="left" width="105" height="105" src="https://i.ebayimg.com/images/g/0NcAAOSw409eeQIA/s-l300.jpg">
#
#
# <center>&nbsp;&nbsp;&nbsp;**Slackmaster Systems**</center>
#
# <center>&nbsp;&nbsp;&nbsp;**Slackmaster Felipe Cafe**</center>
#
# <center>**USA**</center>
# <br>

# %% [markdown]
# ---------------------------------------------------------------------------------------------------------------------
# ---------------------------------------------------------------------------------------------------------------------
# # Press shift and enter at the same time to execute the functions of a cell.  The data stack is sequential so cells later in the notebook rely on previous cells to be executed in the order they are listed from the top of the notebook down.  In the future this notebook will have more GUI input and interaction.  Ultimately this notebook will be completely generic and print a formal report to a pdf file specific to the data release being reviewed once a review is complete.
# >>>>>--SFC-->
# ---------------------------------------------------------------------------------------------------------------------
# ---------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ### 1)	Validate metadata with validation tool (https://mrdata.usgs.gov/validation/) and note compliance issues:

# %%
# Load required Libraries
import sys
import os
import xml.etree.ElementTree as ET
import pandas as pd
import numpy as np
from IPython.core.display import display
from IPython.core.display import HTML
from ipywidgets import *
from IPython.display import display
from IPython.html.widgets import widgets
import datetime
import dateutil.parser
import time
import ssl
import json
import sys
import urllib3 #this library handles the URL stuff
import sciencebasepy as pysb
#Create Function that allows one to implement markdown display when printing
from IPython.display import Markdown, display
import xml.dom.minidom
#from xml.dom.minidom import parse, parseString
def printmd(string):
    display(Markdown(string))
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\html.py:14: ShimWarning: The `IPython.html` package has been deprecated since IPython 4.0. You should import from `notebook` instead. `IPython.html.widgets` has moved to `ipywidgets`.
#   "`IPython.html.widgets` has moved to `ipywidgets`.", ShimWarning)

# %%
#Testing some dashboard stuff: Still need to get the install to work - mabey I'll just use conda instead?
#!{sys.executablepip install jupyter_dashboards
#jupyter dashboards quick-setup --sys-prefix

# %% [markdown]
# # After we get the Science Base Page - how do we get the URLs for the items?

# %% [markdown]
#   ### Check this file to see if it is valid against the FGDC metadata standard (FGDC-STD-001-1998)
#
# ## https://mrdata.usgs.gov/validation/
#
# >>> **COPY RESULTS BELOW:**
#   <title>Error report from mp</title>
#   <style type="text/css">
#     <!--
#     h1 {
#         font-size: large;
#         }
#     table {
#         border-collapse: collapse;
#         }
#     th, td {
#         padding: 4px;
#         }
#     tr {
#         vertical-align: top;
#         }
#       -->
#   </style>
# </head>
# <body>
# <h3>mp 2.9.50 - Peter N. Schweitzer (U.S. Geological Survey)</h3>
# <p>No errors</p>
# <div style="margin: 1em;">
#   <table border="1">
#     <thead>
#       <tr style="background-color: #cceeff;">        <th stype="text-align: left;" scope="col">Type</th>        <th style="text-align: left;" scope="col">Description<br>or line numbers</th>        <th style="text-align: left;" scope="col">Line(s)<br>(or count)</th>      </tr>
#     </thead>
#     <tbody>
#       <tr style="background-color: #CCCCCC;">
#     <td colspan="3">Severity 0: Informative warnings and upgrade notes</td>
#       </tr>
#       <tr style="background-color: #CCFFCC;">
#         <td>Other</td>
#         <td>Info: input file = php2oGsOK.xml</td>
#         <td>0<br/></td>
#       </tr>
#       <tr style="background-color: #CCFFCC;">
#         <td>Other</td>
#         <td>Info: process date = 20201030</td>
#         <td>0<br/></td>
#       </tr>
#       <tr style="background-color: #CCFFCC;">
#         <td>Other</td>
#         <td>Info: process time = 15:55:58</td>
#         <td>0<br/></td>
#       </tr>
#     </tbody>
#   </table>
# </div>
# Generated by <a href="https://geology.usgs.gov/tools/metadata/tools/doc/err2html.html">err2html</a> 2.1.13
# Fri Oct 30 15:55:58 2020
# </body>
#
# <h3 style="color: #006633;">Secondary validation results</h3>
# <table class="table table-condensed table-bordered">
#   <thead>
#     <tr>
#       <th scope="col">Test</th>
#       <th scope="col">Result</th>
#       <th scope="col">Report</th>
#     </tr>
#   </thead>
#   <tbody style="font-size: small;">
#     <tr>
#       <td>Online_Linkage</td>
#       <td style="background-color: #ff9999;">Failure</td>
#       <td style="white-space: pre;">HTTP response code 0 for Online_Linkage in Citation: "https://doi:10.5066/P9H9AVZY"
# </td>
#     </tr>
#     <tr>
#       <td>ISO 19115 Topic Category</td>
#       <td style="background-color: #99ff99;">Success</td>
#       <td style="white-space: pre;">All 2 keywords are valid</td>
#     </tr>
#     <tr>
#       <td>USGS Thesaurus</td>
#       <td style="background-color: #99ff99;">Success</td>
#       <td style="white-space: pre;">All 9 keywords are valid</td>
#     </tr>
#     <tr>
#       <td>Common geographic areas</td>
#       <td>Not found</td>
#       <td style="white-space: pre;">Thesaurus not used in this record</td>
#     </tr>
#     <tr>
#       <td>Format_Name</td>
#       <td>Not found</td>
#       <td style="white-space: pre;">Format_Name does not appear in this record</td>
#     </tr>
#     <tr>
#       <td>Suggest terms</td>
#       <td style="background-color: #ffff99;">Warning</td>
#       <td style="white-space: pre;">No matching terms were found</td>
#     </tr>
#     <tr>
#       <td>Standard name, version</td>
#       <td style="background-color: #99ff99;">Success</td>
#       <td style="white-space: pre;">Metadata_Standard_Name is valid</td>

# %% [markdown]
# ### 2)	 The title conveys the “what, where, when, who, and (if applicable) scale” of the data;

# %%
#Load the metadata file and print data release title - add the correct URL below

from urllib.request import urlopen
from xml.etree.ElementTree import parse

var_url = urlopen('https://www.sciencebase.gov/catalog/file/get/5f066e2682ce21d4c3f90237?f=__disk__63%2F64%2F80%2F63648082412369fa65285e35e8487e08f5db696c')
root = parse(var_url)

for citeinfo in root.iter('citeinfo'):
 title = citeinfo.find('title')

print ('TITLE : \n')
print (title.text)
# Out:
# TITLE :
#
# Airborne magnetic and radiometric survey over northwest Arkansas, 2019-2020; Magnetic Data

# %% [markdown]
# > **Add Title comments here**

# %% [markdown]
# ### 3)	The abstract provides a short statement that allows users to quickly evaluate the content of the dataset:

# %%
#Print out the abstract and purpose
for descript in root.iter('descript'):
 abstract = descript.find('abstract')
 purpose = descript.find('purpose')


print ('ABSTRACT: \n')
print (abstract.text) 
print ('\nPURPOSE: \n')
print (purpose.text)
# Out:
# ABSTRACT:
#
# This publication provides digital flight line data for a high-resolution magnetic survey over an area of northwest Arkansas. The airborne geophysical survey was jointly funded by the USGS National Cooperative Geologic Mapping Program and the Earth Mapping Resource Initiative and was designed to meet the complimentary needs related to geologic mapping and mineral resource research. The survey covers an irregular area 225 by 110 kilometers over the transition between the Ouachita and Ozarks Plateau physiographic provinces and includes 67,614 line-kilometers of magnetic data. Data were collected from a fixed-wing aircraft flown at mean terrain clearance of 167 meters above topography along N-S flight lines spaced at 200 meter intervals. Tie lines were flown in an E-W direction every 3000 meters. Data were collected by EON Geosciences under contract with the USGS using a fixed wing aircraft with a magnetometer mounted in the tail stinger. The survey operated out of the Branson, Missouri airport from October of 2019 to March of 2020. Files that are available in this child item include flight line data for the magnetic survey.
#
# PURPOSE:
#
# The magnetic survey was flown as a component of U.S. Geological Survey (USGS) projects to improve the geologic framework for research related to mineral resource, energy resource, and geologic hazards studies in the area. Results from the survey will aid in providing insight into the magnetic signatures of exposed and concealed geology.

# %% [markdown]
# >  **Add Comments for Abstract Here**

# %% [markdown]
# > **Add Comments for Purpose Here**

# %%
print(root)
tree = root.getroot()
t = ET.tostring(tree)
reparsed = xml.dom.minidom.parseString(t)
metaData = reparsed.toprettyxml(indent="\t")
print (metaData)
# Out:
# <xml.etree.ElementTree.ElementTree object at 0x000001F5B3AAF5C0>
# <?xml version="1.0" ?>
# <metadata>
#
#
# 	<idinfo>
#
#
# 		<citation>
#
#
# 			<citeinfo>
#
#
# 				<origin>McCafferty, A.E.</origin>
#
#
# 				<origin>Brown, P.J.</origin>
#
#
# 				<pubdate>20200929</pubdate>
#
#
# 				<title>Airborne magnetic and radiometric survey over northwest Arkansas, 2019-2020; Magnetic Data</title>
#
#
# 				<geoform>tabular digital data, raster digital data, shapefiles</geoform>
#
#
# 				<pubinfo>
#
#
# 					<pubplace>Denver, CO</pubplace>
#
#
# 					<publish>U.S. Geological Survey</publish>
#
#
# 				</pubinfo>
#
#
# 				<othercit>Additional information about Originators: Anne E. McCafferty, https://orcid.org/0000-0001-5574-9201; Philip J. Brown, http://orcid.org/0000-0002-2415-7462.  Suggested Citation: McCafferty, A.E., and Brown, P.J., 2020, Airborne magnetic and radiometric survey over northwest Arkansas, 2019-2020: U.S. Geological Survey data release, https://doi.org/10.5066/P91O2Y8W.</othercit>
#
#
# 				<onlink>https://doi.org/10.5066/P91O2Y8W</onlink>
#
#
# 			</citeinfo>
#
#
# 		</citation>
#
#
# 		<descript>
#
#
# 			<abstract>This publication provides digital flight line data for a high-resolution magnetic survey over an area of northwest Arkansas. The airborne geophysical survey was jointly funded by the USGS National Cooperative Geologic Mapping Program and the Earth Mapping Resource Initiative and was designed to meet the complimentary needs related to geologic mapping and mineral resource research. The survey covers an irregular area 225 by 110 kilometers over the transition between the Ouachita and Ozarks Plateau physiographic provinces and includes 67,614 line-kilometers of magnetic data. Data were collected from a fixed-wing aircraft flown at mean terrain clearance of 167 meters above topography along N-S flight lines spaced at 200 meter intervals. Tie lines were flown in an E-W direction every 3000 meters. Data were collected by EON Geosciences under contract with the USGS using a fixed wing aircraft with a magnetometer mounted in the tail stinger. The survey operated out of the Branson, Missouri airport from October of 2019 to March of 2020. Files that are available in this child item include flight line data for the magnetic survey.</abstract>
#
#
# 			<purpose>The magnetic survey was flown as a component of U.S. Geological Survey (USGS) projects to improve the geologic framework for research related to mineral resource, energy resource, and geologic hazards studies in the area. Results from the survey will aid in providing insight into the magnetic signatures of exposed and concealed geology.</purpose>
#
#
# 			<supplinf>References cited:
#
# Day, W.D., 2019, The Earth Mapping Resources Initiative (Earth MRI): Mapping the nations critical mineral resources: U.S. Geological Survey Fact Sheet 2019-3007, https://doi.org/10.3133/fs20193007.
#
# This metadata describes the following files:
# USA_Northwest-Arkansas-Airborne-Survey-2019-2020_Raster_TMFIShaded.png
# USA_Northwest-Arkansas-Airborne-Survey-2019-2020_GeoreferencedRaster_ShadedTMFI.tif
# USA_Northwest-Arkansas-Airborne-Survey-2019-2020_GeoreferencedRaster_TMFI.tif
# USA_Northwest-Arkansas-Airborne-Survey-2019-2020_GeoreferencedRaster_VerticalMagneticGradientShaded.tif
# USA_Northwest-Arkansas-Airborne-Survey-2019-2020_GeoreferencedRaster_ShadedTMF.tif
# USA_Northwest-Arkansas-Airborne-Survey-2019-2020_MagneticData.csv</supplinf>
#
#
# 		</descript>
#
#
# 		<timeperd>
#
#
# 			<timeinfo>
#
#
# 				<rngdates>
#
#
# 					<begdate>20191005</begdate>
#
#
# 					<enddate>20200307</enddate>
#
#
# 				</rngdates>
#
#
# 			</timeinfo>
#
#
# 			<current>ground condition</current>
#
#
# 		</timeperd>
#
#
# 		<status>
#
#
# 			<progress>Complete</progress>
#
#
# 			<update>Not planned</update>
#
#
# 		</status>
#
#
# 		<spdom>
#
#
# 			<bounding>
#
#
# 				<westbc>-91.318886</westbc>
#
#
# 				<eastbc>-93.825821</eastbc>
#
#
# 				<northbc>36.500267</northbc>
#
#
# 				<southbc>35.513279</southbc>
#
#
# 			</bounding>
#
#
# 		</spdom>
#
#
# 		<keywords>
#
#
# 			<theme>
#
#
# 				<themekt>USGS Thesaurus</themekt>
#
#
# 				<themekey>magnetic field (earth)</themekey>
#
#
# 				<themekey>geophysics</themekey>
#
#
# 				<themekey>geospatial datasets</themekey>
#
#
# 				<themekey>aeromagnetic surveying</themekey>
#
#
# 				<themekey>aeroradiometric surveying</themekey>
#
#
# 				<themekey>potassium</themekey>
#
#
# 				<themekey>uranium</themekey>
#
#
# 				<themekey>thorium</themekey>
#
#
# 				<themekey>radon</themekey>
#
#
# 			</theme>
#
#
# 			<theme>
#
#
# 				<themekt>ISO 19115 Topic Category</themekt>
#
#
# 				<themekey>geoscientificInformation</themekey>
#
#
# 				<themekey>economy</themekey>
#
#
# 			</theme>
#
#
# 			<theme>
#
#
# 				<themekt>None</themekt>
#
#
# 				<themekey>Mineral Resources Program</themekey>
#
#
# 				<themekey>MRP</themekey>
#
#
# 				<themekey>Geology, Geophysics, and Geochemistry Science Center</themekey>
#
#
# 				<themekey>GGGSC</themekey>
#
#
# 				<themekey>Earth Mapping Resources Initiative</themekey>
#
#
# 				<themekey>EarthMRI</themekey>
#
#
# 				<themekey>horizontal magnetic gradiometry</themekey>
#
#
# 				<themekey>vertical magnetic gradient</themekey>
#
#
# 				<themekey>airborne geophysical survey</themekey>
#
#
# 				<themekey>U.S. Geological Survey</themekey>
#
#
# 				<themekey>USGS</themekey>
#
#
# 				<themekey>Association of American State Geologists</themekey>
#
#
# 				<themekey>AASG</themekey>
#
#
# 				<themekey>EON Geosciences, Inc.</themekey>
#
#
# 				<themekey>Rn</themekey>
#
#
# 			</theme>
#
#
# 			<theme>
#
#
# 				<themekt>USGS Metadata Identifier</themekt>
#
#
# 				<themekey>USGS:5f066e2682ce21d4c3f90237</themekey>
#
#
# 			</theme>
#
#
# 			<place>
#
#
# 				<placekt>USGS Geographic Names Information System (GNIS), https://geonames.usgs.gov</placekt>
#
#
# 				<placekey>Boston Mountains</placekey>
#
#
# 				<placekey>Carroll County</placekey>
#
#
# 				<placekey>Madison County</placekey>
#
#
# 				<placekey>Franklin County</placekey>
#
#
# 				<placekey>Johnson County</placekey>
#
#
# 				<placekey>Pope County</placekey>
#
#
# 				<placekey>Newton County</placekey>
#
#
# 				<placekey>Boone County</placekey>
#
#
# 				<placekey>Marion County</placekey>
#
#
# 				<placekey>Baxter County</placekey>
#
#
# 				<placekey>Stone County</placekey>
#
#
# 				<placekey>Izard County</placekey>
#
#
# 				<placekey>Sharp County</placekey>
#
#
# 				<placekey>Independence County</placekey>
#
#
# 				<placekey>Lawrence County</placekey>
#
#
# 				<placekey>Searcy County</placekey>
#
#
# 				<placekey>Washington County</placekey>
#
#
# 				<placekey>Johnson County</placekey>
#
#
# 				<placekey>Van Buren County</placekey>
#
#
# 				<placekey>Barry County</placekey>
#
#
# 			</place>
#
#
# 			<place>
#
#
# 				<placekt>Common geographic areas</placekt>
#
#
# 				<placekey>Arkansas</placekey>
#
#
# 				<placekey>United States</placekey>
#
#
# 			</place>
#
#
# 			<place>
#
#
# 				<placekt>None</placekt>
#
#
# 				<placekey>USA</placekey>
#
#
# 				<placekey>United States of America</placekey>
#
#
# 				<placekey>Ouachita Plateau</placekey>
#
#
# 				<placekey>Ozarks Plateau</placekey>
#
#
# 			</place>
#
#
# 		</keywords>
#
#
# 		<accconst>None. Please see 'Distribution Info' for details.</accconst>
#
#
# 		<useconst>Any use of trade, firm, or product names is for descriptive purposes only and does not imply endorsement by the U.S. Government. Although these data have been processed successfully on a computer system at the U.S. Geological Survey (USGS), no warranty expressed or implied is made regarding the display or utility of the data for other purposes, nor on all computer systems, nor shall the act of distribution constitute any such warranty. The USGS or the U.S. Government shall not be held liable for improper or incorrect use of the data described and/or contained herein. Acknowledgment of the U.S. Geological Survey would be appreciated in products derived from these data.</useconst>
#
#
# 		<ptcontac>
#
#
# 			<cntinfo>
#
#
# 				<cntorgp>
#
#
# 					<cntorg>U.S. Geological Survey</cntorg>
#
#
# 					<cntper>Anne E. McCafferty</cntper>
#
#
# 				</cntorgp>
#
#
# 				<cntpos>Research Geophysicist</cntpos>
#
#
# 				<cntaddr>
#
#
# 					<addrtype>mailing and physical</addrtype>
#
#
# 					<address>PO Box 25046, Mail Stop 973, Bldg 20, Denver Federal Center, W 6th Ave and Kipling St</address>
#
#
# 					<city>Denver</city>
#
#
# 					<state>CO</state>
#
#
# 					<postal>80225-0046</postal>
#
#
# 					<country>US</country>
#
#
# 				</cntaddr>
#
#
# 				<cntvoice>303-236-1397</cntvoice>
#
#
# 				<cntemail>anne@usgs.gov</cntemail>
#
#
# 			</cntinfo>
#
#
# 		</ptcontac>
#
#
# 		<datacred>This survey and release of the dataset was funded by the Earth Mapping Resources Initiative (Earth MRI).</datacred>
#
#
# 	</idinfo>
#
#
# 	<dataqual>
#
#
# 		<attracc>
#
#
# 			<attraccr>Daily quality control of raw radiometric and magnetic data was performed by the contractor. Further quality control measures occurred post flight by the contractor and USGS scientist-in-charge before approval and acceptance of the final data. The data have been peer reviewed and compared with related ancillary data.</attraccr>
#
#
# 		</attracc>
#
#
# 		<logic>Data were visually inspected for reasonableness and spatial consistency.</logic>
#
#
# 		<complete>Data set is considered complete for the information presented, as described in the abstract. Users are advised to read the rest of the metadata record carefully for additional details.</complete>
#
#
# 		<posacc>
#
#
# 			<horizpa>
#
#
# 				<horizpar>Field quality control and assurance procedures were undertaken by the Eon Geosciences Inc. field crew and are described in the contractors report included with this data release.</horizpar>
#
#
# 			</horizpa>
#
#
# 			<vertacc>
#
#
# 				<vertaccr>Field quality control and assurance procedures were undertaken by the Eon Geosciences Inc. field crew and are described in the contractors report included with this data release.</vertaccr>
#
#
# 			</vertacc>
#
#
# 		</posacc>
#
#
# 		<lineage>
#
#
# 			<procstep>
#
#
# 				<procdesc>The airborne survey was flown under contract to the U.S. Geological Survey by EON Geosciences Inc., from October 5, 2019 to March 7, 2020. The magnetic data were acquired with a Geometrics G-822A cesium-vapour split-beam sensor. The radiometric data were acquired with a Radiation Solutions RS-500 series multi-channel gamma-ray spectrometers, models RSX-5 and RSX-4, with 1,024 channels, for a total volume of 33.6 liters downward-looking and 8.4 liters (C-FEON) or 4.2 liters (C-GPTB) upward-looking crystals (for measuring effects of atmospheric radon). Data were collected along east-west flight lines spaced 200 meters (m) apart with north-south tie lines flown every 3,000 meters. A mean terrain clearance of 80 m was maintained except where safety dictated a higher elevation. A total of 66,477 line-kilometers of data were collected.</procdesc>
#
#
# 				<procdate>20191005</procdate>
#
#
# 			</procstep>
#
#
# 			<procstep>
#
#
# 				<procdesc>Preliminary magnetic and radiometric data processing was undertaken by EON Geosciences, Inc. of Montreal, Quebec, Canada. This processing workflow is described in the contractors report included with this data release.</procdesc>
#
#
# 				<procdate>20200316</procdate>
#
#
# 			</procstep>
#
#
# 			<procstep>
#
#
# 				<procdesc>Final data and contractors report were accepted and received by USGS from EON Geosciences, Inc.</procdesc>
#
#
# 				<procdate>20200629</procdate>
#
#
# 			</procstep>
#
#
# 			<procstep>
#
#
# 				<procdesc>Created georeferenced rasters of the data grids provided by the contractor.  Created Esri shapefiles of area footprint and line paths for the survey using the line data provided by the contractor.</procdesc>
#
#
# 				<procdate>20200707</procdate>
#
#
# 			</procstep>
#
#
# 			<procstep>
#
#
# 				<procdesc>Final data were exported to CSV-format to meet open data requirements.</procdesc>
#
#
# 				<procdate>20200707</procdate>
#
#
# 			</procstep>
#
#
# 		</lineage>
#
#
# 	</dataqual>
#
#
# 	<spdoinfo>
#
#
# 		<direct>Raster</direct>
#
#
# 	</spdoinfo>
#
#
# 	<spref>
#
#
# 		<horizsys>
#
#
# 			<geograph>
#
#
# 				<latres>0.000001</latres>
#
#
# 				<longres>0.000001</longres>
#
#
# 				<geogunit>Decimal degrees</geogunit>
#
#
# 			</geograph>
#
#
# 			<geodetic>
#
#
# 				<horizdn>WGS_1984</horizdn>
#
#
# 				<ellips>WGS_1984</ellips>
#
#
# 				<semiaxis>6378206.4</semiaxis>
#
#
# 				<denflat>294.9786982</denflat>
#
#
# 			</geodetic>
#
#
# 		</horizsys>
#
#
# 	</spref>
#
#
# 	<eainfo>
#
#
# 		<detailed>
#
#
# 			<enttyp>
#
#
# 				<enttypl>USA_Northwest-Arkansas-Airborne-Survey-2019-2020_MagneticData.csv</enttypl>
#
#
# 				<enttypd>Table containing attribute information associated with the magnetic data set.</enttypd>
#
#
# 				<enttypds>U.S. Geological Survey</enttypds>
#
#
# 			</enttyp>
#
#
# 			<attr>
#
#
# 				<attrlabl>baltl</attrlabl>
#
#
# 				<attrdef>Baro altitude, raw. MSL, computed from measured pressure and temperature</attrdef>
#
#
# 				<attrdefs>EON GEOSCIENCES INC.</attrdefs>
#
#
# 				<attrdomv>
#
#
# 					<rdom>
#
#
# 						<rdommin>14.9452438354492</rdommin>
#
#
# 						<rdommax>899.5800170898441</rdommax>
#
#
# 						<attrunit>meters</attrunit>
#
#
# 					</rdom>
#
#
# 				</attrdomv>
#
#
# 			</attr>
#
#
# 			<attr>
#
#
# 				<attrlabl>baltlc</attrlabl>
#
#
# 				<attrdef>Baro altitude, edited. MSL, low-pass filtered against noise and spikes</attrdef>
#
#
# 				<attrdefs>EON GEOSCIENCES INC.</attrdefs>
#
#
# 				<attrdomv>
#
#
# 					<rdom>
#
#
# 						<rdommin>17.0135078430176</rdommin>
#
#
# 						<rdommax>899.485107421875</rdommax>
#
#
# 						<attrunit>meters</attrunit>
#
#
# 					</rdom>
#
#
# 				</attrdomv>
#
#
# 			</attr>
#
#
# 			<attr>
#
#
# 				<attrlabl>barom</attrlabl>
#
#
# 				<attrdef>Barometric altitude above MSL. Same as [baltlc]</attrdef>
#
#
# 				<attrdefs>EON GEOSCIENCES INC.</attrdefs>
#
#
# 				<attrdomv>
#
#
# 					<rdom>
#
#
# 						<rdommin>17.0135078430176</rdommin>
#
#
# 						<rdommax>899.485107421875</rdommax>
#
#
# 						<attrunit>meters</attrunit>
#
#
# 					</rdom>
#
#
# 				</attrdomv>
#
#
# 			</attr>
#
#
# 			<attr>
#
#
# 				<attrlabl>baseB</attrlabl>
#
#
# 				<attrdef>Main mag base, edited. Edited against cultural signal and noise</attrdef>
#
#
# 				<attrdefs>EON GEOSCIENCES INC.</attrdefs>
#
#
# 				<attrdomv>
#
#
# 					<rdom>
#
#
# 						<rdommin>50788.08984375</rdommin>
#
#
# 						<rdommax>50856.87890625</rdommax>
#
#
# 						<attrunit>nanoteslas</attrunit>
#
#
# 					</rdom>
#
#
# 				</attrdomv>
#
#
# 			</attr>
#
#
# 			<attr>
#
#
# 				<attrlabl>baseBo</attrlabl>
#
#
# 				<attrdef>Main mag base, raw	Raw main mag base station</attrdef>
#
#
# 				<attrdefs>EON GEOSCIENCES INC.</attrdefs>
#
#
# 				<attrdomv>
#
#
# 					<rdom>
#
#
# 						<rdommin>50339.41796875</rdommin>
#
#
# 						<rdommax>51018.91015625</rdommax>
#
#
# 						<attrunit>nanoteslas</attrunit>
#
#
# 					</rdom>
#
#
# 				</attrdomv>
#
#
# 			</attr>
#
#
# 			<attr>
#
#
# 				<attrlabl>date</attrlabl>
#
#
# 				<attrdef>Acquisition date. Start of acquisition, UTC</attrdef>
#
#
# 				<attrdefs>EON GEOSCIENCES INC.</attrdefs>
#
#
# 				<attrdomv>
#
#
# 					<rdom>
#
#
# 						<rdommin>2019/10/27</rdommin>
#
#
# 						<rdommax>2020/03/07</rdommax>
#
#
# 						<attrunit>yyyy/mm/dd</attrunit>
#
#
# 					</rdom>
#
#
# 				</attrdomv>
#
#
# 			</attr>
#
#
# 			<attr>
#
#
# 				<attrlabl>directn</attrlabl>
#
#
# 				<attrdef>Flight line direction, azimuth degrees from north.</attrdef>
#
#
# 				<attrdefs>EON GEOSCIENCES INC.</attrdefs>
#
#
# 				<attrdomv>
#
#
# 					<rdom>
#
#
# 						<rdommin>0</rdommin>
#
#
# 						<rdommax>270</rdommax>
#
#
# 						<attrunit>degrees</attrunit>
#
#
# 					</rdom>
#
#
# 				</attrdomv>
#
#
# 			</attr>
#
#
# 			<attr>
#
#
# 				<attrlabl>drape</attrlabl>
#
#
# 				<attrdef>Drape altitude. MSL, planned flight surface for navigation</attrdef>
#
#
# 				<attrdefs>EON GEOSCIENCES INC.</attrdefs>
#
#
# 				<attrdomv>
#
#
# 					<rdom>
#
#
# 						<rdommin>157.593338012695</rdommin>
#
#
# 						<rdommax>933.3391723632809</rdommax>
#
#
# 						<attrunit>meters</attrunit>
#
#
# 					</rdom>
#
#
# 				</attrdomv>
#
#
# 			</attr>
#
#
# 			<attr>
#
#
# 				<attrlabl>DTMc</attrlabl>
#
#
# 				<attrdef>Digital terrain model. MSL, DTM model, [z-2.5m-raltlc], GPS ant. 2.5m above radar ant.</attrdef>
#
#
# 				<attrdefs>EON GEOSCIENCES INC.</attrdefs>
#
#
# 				<attrdomv>
#
#
# 					<rdom>
#
#
# 						<rdommin>59.8533935546875</rdommin>
#
#
# 						<rdommax>789.855224609375</rdommax>
#
#
# 						<attrunit>meters</attrunit>
#
#
# 					</rdom>
#
#
# 				</attrdomv>
#
#
# 			</attr>
#
#
# 			<attr>
#
#
# 				<attrlabl>DTMo</attrlabl>
#
#
# 				<attrdef>Digital terrain model. MSL, DTM model, [z-2.5m-raltl], GPS ant. 2.5m above radar ant.</attrdef>
#
#
# 				<attrdefs>EON GEOSCIENCES INC.</attrdefs>
#
#
# 				<attrdomv>
#
#
# 					<rdom>
#
#
# 						<rdommin>57.6822357177734</rdommin>
#
#
# 						<rdommax>782.636962890625</rdommax>
#
#
# 						<attrunit>meters</attrunit>
#
#
# 					</rdom>
#
#
# 				</attrdomv>
#
#
# 			</attr>
#
#
# 			<attr>
#
#
# 				<attrlabl>fid10</attrlabl>
#
#
# 				<attrdef>Fiducial, Oasis. RMS system fiducial</attrdef>
#
#
# 				<attrdefs>EON GEOSCIENCES INC.</attrdefs>
#
#
# 				<attrdomv>
#
#
# 					<rdom>
#
#
# 						<rdommin>48639.0</rdommin>
#
#
# 						<rdommax>87331.0</rdommax>
#
#
# 						<attrunit>sec</attrunit>
#
#
# 					</rdom>
#
#
# 				</attrdomv>
#
#
# 			</attr>
#
#
# 			<attr>
#
#
# 				<attrlabl>fiducial</attrlabl>
#
#
# 				<attrdef>Fiducial number, same as [fid10] (10Hz version)</attrdef>
#
#
# 				<attrdefs>EON GEOSCIENCES INC.</attrdefs>
#
#
# 				<attrdomv>
#
#
# 					<rdom>
#
#
# 						<rdommin>48639.0</rdommin>
#
#
# 						<rdommax>87331.0</rdommax>
#
#
# 						<attrunit>sec</attrunit>
#
#
# 					</rdom>
#
#
# 				</attrdomv>
#
#
# 			</attr>
#
#
# 			<attr>
#
#
# 				<attrlabl>flt</attrlabl>
#
#
# 				<attrdef>Flight number</attrdef>
#
#
# 				<attrdefs>EON GEOSCIENCES INC.</attrdefs>
#
#
# 				<attrdomv>
#
#
# 					<rdom>
#
#
# 						<rdommin>21</rdommin>
#
#
# 						<rdommax>257</rdommax>
#
#
# 						<attrunit>none</attrunit>
#
#
# 					</rdom>
#
#
# 				</attrdomv>
#
#
# 			</attr>
#
#
# 			<attr>
#
#
# 				<attrlabl>hgps</attrlabl>
#
#
# 				<attrdef>hgps</attrdef>
#
#
# 				<attrdefs>EON GEOSCIENCES INC.</attrdefs>
#
#
# 				<attrdomv>
#
#
# 					<rdom>
#
#
# 						<rdommin>13:30:39</rdommin>
#
#
# 						<rdommax>24:15:31</rdommax>
#
#
# 						<attrunit>UTC hour</attrunit>
#
#
# 					</rdom>
#
#
# 				</attrdomv>
#
#
# 			</attr>
#
#
# 			<attr>
#
#
# 				<attrlabl>jul_day</attrlabl>
#
#
# 				<attrdef>Julian day flown.</attrdef>
#
#
# 				<attrdefs>EON GEOSCIENCES INC.</attrdefs>
#
#
# 				<attrdomv>
#
#
# 					<rdom>
#
#
# 						<rdommin>19</rdommin>
#
#
# 						<rdommax>345</rdommax>
#
#
# 						<attrunit>ddd</attrunit>
#
#
# 					</rdom>
#
#
# 				</attrdomv>
#
#
# 			</attr>
#
#
# 			<attr>
#
#
# 				<attrlabl>lat</attrlabl>
#
#
# 				<attrdef>Latitude, decimal degrees.</attrdef>
#
#
# 				<attrdefs>EON GEOSCIENCES INC.</attrdefs>
#
#
# 				<attrdomv>
#
#
# 					<rdom>
#
#
# 						<rdommin>35.513278961181605</rdommin>
#
#
# 						<rdommax>36.5002670288086</rdommax>
#
#
# 						<attrunit>degrees</attrunit>
#
#
# 					</rdom>
#
#
# 				</attrdomv>
#
#
# 			</attr>
#
#
# 			<attr>
#
#
# 				<attrlabl>latitude</attrlabl>
#
#
# 				<attrdef>Latitude, decimal degrees, same as [lat].</attrdef>
#
#
# 				<attrdefs>EON GEOSCIENCES INC.</attrdefs>
#
#
# 				<attrdomv>
#
#
# 					<rdom>
#
#
# 						<rdommin>35.513278961181605</rdommin>
#
#
# 						<rdommax>36.5002670288086</rdommax>
#
#
# 						<attrunit>degrees</attrunit>
#
#
# 					</rdom>
#
#
# 				</attrdomv>
#
#
# 			</attr>
#
#
# 			<attr>
#
#
# 				<attrlabl>line</attrlabl>
#
#
# 				<attrdef>Line number, edited lll: planned line number, n: segment code.</attrdef>
#
#
# 				<attrdefs>EON GEOSCIENCES INC.</attrdefs>
#
#
# 				<attrdomv>
#
#
# 					<rdom>
#
#
# 						<rdommin>20010</rdommin>
#
#
# 						<rdommax>50370</rdommax>
#
#
# 						<attrunit>llln</attrunit>
#
#
# 					</rdom>
#
#
# 				</attrdomv>
#
#
# 			</attr>
#
#
# 			<attr>
#
#
# 				<attrlabl>line_no</attrlabl>
#
#
# 				<attrdef>Flight line number, same as [line].</attrdef>
#
#
# 				<attrdefs>EON GEOSCIENCES INC.</attrdefs>
#
#
# 				<attrdomv>
#
#
# 					<rdom>
#
#
# 						<rdommin>20010</rdommin>
#
#
# 						<rdommax>50370</rdommax>
#
#
# 						<attrunit>llln</attrunit>
#
#
# 					</rdom>
#
#
# 				</attrdomv>
#
#
# 			</attr>
#
#
# 			<attr>
#
#
# 				<attrlabl>lon</attrlabl>
#
#
# 				<attrdef>Longitude decimal degrees.</attrdef>
#
#
# 				<attrdefs>EON GEOSCIENCES INC.</attrdefs>
#
#
# 				<attrdomv>
#
#
# 					<rdom>
#
#
# 						<rdommin>-93.8258209228516</rdommin>
#
#
# 						<rdommax>-91.3188858032227</rdommax>
#
#
# 						<attrunit>degrees</attrunit>
#
#
# 					</rdom>
#
#
# 				</attrdomv>
#
#
# 			</attr>
#
#
# 			<attr>
#
#
# 				<attrlabl>longitud</attrlabl>
#
#
# 				<attrdef>Decimal degrees, same as [lon].</attrdef>
#
#
# 				<attrdefs>EON GEOSCIENCES INC.</attrdefs>
#
#
# 				<attrdomv>
#
#
# 					<rdom>
#
#
# 						<rdommin>-93.8258209228516</rdommin>
#
#
# 						<rdommax>-91.3188858032227</rdommax>
#
#
# 						<attrunit>degrees</attrunit>
#
#
# 					</rdom>
#
#
# 				</attrdomv>
#
#
# 			</attr>
#
#
# 			<attr>
#
#
# 				<attrlabl>m3l</attrlabl>
#
#
# 				<attrdef>Compensated TMF, raw. Sensor 3, tail stinger.</attrdef>
#
#
# 				<attrdefs>EON GEOSCIENCES INC.</attrdefs>
#
#
# 				<attrdomv>
#
#
# 					<rdom>
#
#
# 						<rdommin>35250.01953125</rdommin>
#
#
# 						<rdommax>53859.76171875</rdommax>
#
#
# 						<attrunit>nanoteslas</attrunit>
#
#
# 					</rdom>
#
#
# 				</attrdomv>
#
#
# 			</attr>
#
#
# 			<attr>
#
#
# 				<attrlabl>mfluxX</attrlabl>
#
#
# 				<attrdef>Fluxgate MF-X, raw. Longitudinal vector fluxgate sensor.</attrdef>
#
#
# 				<attrdefs>EON GEOSCIENCES INC.</attrdefs>
#
#
# 				<attrdomv>
#
#
# 					<rdom>
#
#
# 						<rdommin>-50328.4296875</rdommin>
#
#
# 						<rdommax>42193.26953125</rdommax>
#
#
# 						<attrunit>nanoteslas</attrunit>
#
#
# 					</rdom>
#
#
# 				</attrdomv>
#
#
# 			</attr>
#
#
# 			<attr>
#
#
# 				<attrlabl>mfluxY</attrlabl>
#
#
# 				<attrdef>Fluxgate MF-Y, raw. Transverse vector fluxgate sensor.</attrdef>
#
#
# 				<attrdefs>EON GEOSCIENCES INC.</attrdefs>
#
#
# 				<attrdomv>
#
#
# 					<rdom>
#
#
# 						<rdommin>-36796.46875</rdommin>
#
#
# 						<rdommax>33077.49609375</rdommax>
#
#
# 						<attrunit>nanoteslas</attrunit>
#
#
# 					</rdom>
#
#
# 				</attrdomv>
#
#
# 			</attr>
#
#
# 			<attr>
#
#
# 				<attrlabl>mfluxZ</attrlabl>
#
#
# 				<attrdef>Fluxgate MF-Z, raw. Vertical vector fluxgate ensor.</attrdef>
#
#
# 				<attrdefs>EON GEOSCIENCES INC.</attrdefs>
#
#
# 				<attrdomv>
#
#
# 					<rdom>
#
#
# 						<rdommin>-11719.4443359375</rdommin>
#
#
# 						<rdommax>50388.6953125</rdommax>
#
#
# 						<attrunit>nanoteslas</attrunit>
#
#
# 					</rdom>
#
#
# 				</attrdomv>
#
#
# 			</attr>
#
#
# 			<attr>
#
#
# 				<attrlabl>mreslc</attrlabl>
#
#
# 				<attrdef>TMF, partial IGRF removed. Partial IGRF to drape surface removed from m3l.</attrdef>
#
#
# 				<attrdefs>EON GEOSCIENCES INC.</attrdefs>
#
#
# 				<attrdomv>
#
#
# 					<rdom>
#
#
# 						<rdommin>50083.84375</rdommin>
#
#
# 						<rdommax>50958.0234375</rdommax>
#
#
# 						<attrunit>nanoteslas</attrunit>
#
#
# 					</rdom>
#
#
# 				</attrdomv>
#
#
# 			</attr>
#
#
# 			<attr>
#
#
# 				<attrlabl>mreslcb</attrlabl>
#
#
# 				<attrdef>TMF, diurnals corrected. Filtered (LP 7500m) and zero-average diurnals removed from mreslc</attrdef>
#
#
# 				<attrdefs>EON GEOSCIENCES INC.</attrdefs>
#
#
# 				<attrdomv>
#
#
# 					<rdom>
#
#
# 						<rdommin>50095.1640625</rdommin>
#
#
# 						<rdommax>50930.49609375</rdommax>
#
#
# 						<attrunit>nanoteslas</attrunit>
#
#
# 					</rdom>
#
#
# 				</attrdomv>
#
#
# 			</attr>
#
#
# 			<attr>
#
#
# 				<attrlabl>mreslct</attrlabl>
#
#
# 				<attrdef>TMF, Taylor signal removed. Taylor-corrected for drape deviations</attrdef>
#
#
# 				<attrdefs>EON GEOSCIENCES INC.</attrdefs>
#
#
# 				<attrdomv>
#
#
# 					<rdom>
#
#
# 						<rdommin>50096.11328125</rdommin>
#
#
# 						<rdommax>50932.515625</rdommax>
#
#
# 						<attrunit>nanoteslas</attrunit>
#
#
# 					</rdom>
#
#
# 				</attrdomv>
#
#
# 			</attr>
#
#
# 			<attr>
#
#
# 				<attrlabl>mreslvl</attrlabl>
#
#
# 				<attrdef>TMF, levelled. Intersection levelling of mreslcb</attrdef>
#
#
# 				<attrdefs>EON GEOSCIENCES INC.</attrdefs>
#
#
# 				<attrdomv>
#
#
# 					<rdom>
#
#
# 						<rdommin>50095.63671875</rdommin>
#
#
# 						<rdommax>50929.671875</rdommax>
#
#
# 						<attrunit>nanoteslas</attrunit>
#
#
# 					</rdom>
#
#
# 				</attrdomv>
#
#
# 			</attr>
#
#
# 			<attr>
#
#
# 				<attrlabl>mreslvld</attrlabl>
#
#
# 				<attrdef>TMF, micro-levelled Micro-levelling correction applied on mreslct.</attrdef>
#
#
# 				<attrdefs>EON GEOSCIENCES INC.</attrdefs>
#
#
# 				<attrdomv>
#
#
# 					<rdom>
#
#
# 						<rdommin>50096.1640625</rdommin>
#
#
# 						<rdommax>50932.45703125</rdommax>
#
#
# 						<attrunit>nanoteslas</attrunit>
#
#
# 					</rdom>
#
#
# 				</attrdomv>
#
#
# 			</attr>
#
#
# 			<attr>
#
#
# 				<attrlabl>mreslvldi</attrlabl>
#
#
# 				<attrdef>IGRF residual of TMF. Using 2015 model with fixed date, 2020-01-01 and altitude 549.89m.</attrdef>
#
#
# 				<attrdefs>EON GEOSCIENCES INC.</attrdefs>
#
#
# 				<attrdomv>
#
#
# 					<rdom>
#
#
# 						<rdommin>-444.865356445313</rdommin>
#
#
# 						<rdommax>594.9659423828131</rdommax>
#
#
# 						<attrunit>nanoteslas</attrunit>
#
#
# 					</rdom>
#
#
# 				</attrdomv>
#
#
# 			</attr>
#
#
# 			<attr>
#
#
# 				<attrlabl>radar</attrlabl>
#
#
# 				<attrdef>Radar altitude above ground, Same as [raltlc], 10Hz version.</attrdef>
#
#
# 				<attrdefs>EON GEOSCIENCES INC.</attrdefs>
#
#
# 				<attrdomv>
#
#
# 					<rdom>
#
#
# 						<rdommin>58.914302825927706</rdommin>
#
#
# 						<rdommax>479.855834960938</rdommax>
#
#
# 						<attrunit>meters</attrunit>
#
#
# 					</rdom>
#
#
# 				</attrdomv>
#
#
# 			</attr>
#
#
# 			<attr>
#
#
# 				<attrlabl>raltl</attrlabl>
#
#
# 				<attrdef>Radar altitude, raw. AGL, linear transformation from raw readings.</attrdef>
#
#
# 				<attrdefs>EON GEOSCIENCES INC.</attrdefs>
#
#
# 				<attrdomv>
#
#
# 					<rdom>
#
#
# 						<rdommin>60.7630958557129</rdommin>
#
#
# 						<rdommax>493.358825683594</rdommax>
#
#
# 						<attrunit>meters</attrunit>
#
#
# 					</rdom>
#
#
# 				</attrdomv>
#
#
# 			</attr>
#
#
# 			<attr>
#
#
# 				<attrlabl>raltlc</attrlabl>
#
#
# 				<attrdef>Radar altitude, edited. AGL, low-pass filtered against noise, spikes and jumps.</attrdef>
#
#
# 				<attrdefs>EON GEOSCIENCES INC.</attrdefs>
#
#
# 				<attrdomv>
#
#
# 					<rdom>
#
#
# 						<rdommin>58.914302825927706</rdommin>
#
#
# 						<rdommax>479.855834960938</rdommax>
#
#
# 						<attrunit>meters</attrunit>
#
#
# 					</rdom>
#
#
# 				</attrdomv>
#
#
# 			</attr>
#
#
# 			<attr>
#
#
# 				<attrlabl>resmag</attrlabl>
#
#
# 				<attrdef>CResidual magnetic value. Same as [mreslvldi].</attrdef>
#
#
# 				<attrdefs>EON GEOSCIENCES INC.</attrdefs>
#
#
# 				<attrdomv>
#
#
# 					<rdom>
#
#
# 						<rdommin>-444.865356445313</rdommin>
#
#
# 						<rdommax>594.9659423828131</rdommax>
#
#
# 						<attrunit>nanoteslas</attrunit>
#
#
# 					</rdom>
#
#
# 				</attrdomv>
#
#
# 			</attr>
#
#
# 			<attr>
#
#
# 				<attrlabl>topoSRTM</attrlabl>
#
#
# 				<attrdef>Published terrain model MSL, DTM model from SRTM grid.</attrdef>
#
#
# 				<attrdefs>EON GEOSCIENCES INC.</attrdefs>
#
#
# 				<attrdomv>
#
#
# 					<rdom>
#
#
# 						<rdommin>62.067501068115206</rdommin>
#
#
# 						<rdommax>788.2978515625</rdommax>
#
#
# 						<attrunit>nanoteslas</attrunit>
#
#
# 					</rdom>
#
#
# 				</attrdomv>
#
#
# 			</attr>
#
#
# 			<attr>
#
#
# 				<attrlabl>totmag</attrlabl>
#
#
# 				<attrdef>Corrected TMF value. Same as [mreslvld].</attrdef>
#
#
# 				<attrdefs>EON GEOSCIENCES INC.</attrdefs>
#
#
# 				<attrdomv>
#
#
# 					<rdom>
#
#
# 						<rdommin>50096.1640625</rdommin>
#
#
# 						<rdommax>50932.45703125</rdommax>
#
#
# 						<attrunit>nanoteslas</attrunit>
#
#
# 					</rdom>
#
#
# 				</attrdomv>
#
#
# 			</attr>
#
#
# 			<attr>
#
#
# 				<attrlabl>um3l</attrlabl>
#
#
# 				<attrdef>Uncompensated TMF, raw. Sensor 3, tail stinger.</attrdef>
#
#
# 				<attrdefs>EON GEOSCIENCES INC.</attrdefs>
#
#
# 				<attrdomv>
#
#
# 					<rdom>
#
#
# 						<rdommin>35238.26171875</rdommin>
#
#
# 						<rdommax>53852.65625</rdommax>
#
#
# 						<attrunit>nanoteslas</attrunit>
#
#
# 					</rdom>
#
#
# 				</attrdomv>
#
#
# 			</attr>
#
#
# 			<attr>
#
#
# 				<attrlabl>x</attrlabl>
#
#
# 				<attrdef>UTM Easting WGS-84, Z15N, differential PP-DGPS.</attrdef>
#
#
# 				<attrdefs>EON GEOSCIENCES INC.</attrdefs>
#
#
# 				<attrdomv>
#
#
# 					<rdom>
#
#
# 						<rdommin>425777.875</rdommin>
#
#
# 						<rdommax>651590.9375</rdommax>
#
#
# 						<attrunit>meters</attrunit>
#
#
# 					</rdom>
#
#
# 				</attrdomv>
#
#
# 			</attr>
#
#
# 			<attr>
#
#
# 				<attrlabl>y</attrlabl>
#
#
# 				<attrdef>UTM Northing WGS-84, Z15N, differential PP-DGPS.</attrdef>
#
#
# 				<attrdefs>EON GEOSCIENCES INC.</attrdefs>
#
#
# 				<attrdomv>
#
#
# 					<rdom>
#
#
# 						<rdommin>3930246.25</rdommin>
#
#
# 						<rdommax>4039511.5</rdommax>
#
#
# 						<attrunit>meters</attrunit>
#
#
# 					</rdom>
#
#
# 				</attrdomv>
#
#
# 			</attr>
#
#
# 			<attr>
#
#
# 				<attrlabl>year</attrlabl>
#
#
# 				<attrdef>year</attrdef>
#
#
# 				<attrdefs>EON GEOSCIENCES INC.</attrdefs>
#
#
# 				<attrdomv>
#
#
# 					<rdom>
#
#
# 						<rdommin>2019</rdommin>
#
#
# 						<rdommax>2020</rdommax>
#
#
# 						<attrunit>yyyy</attrunit>
#
#
# 					</rdom>
#
#
# 				</attrdomv>
#
#
# 			</attr>
#
#
# 			<attr>
#
#
# 				<attrlabl>z</attrlabl>
#
#
# 				<attrdef>GPS altitude, unedited MSL, differential PP-DGPS.</attrdef>
#
#
# 				<attrdefs>EON GEOSCIENCES INC.</attrdefs>
#
#
# 				<attrdomv>
#
#
# 					<rdom>
#
#
# 						<rdommin>157.460098266602</rdommin>
#
#
# 						<rdommax>942.005126953125</rdommax>
#
#
# 						<attrunit>meters</attrunit>
#
#
# 					</rdom>
#
#
# 				</attrdomv>
#
#
# 			</attr>
#
#
# 		</detailed>
#
#
# 		<detailed>
#
#
# 			<enttyp>
#
#
# 				<enttypl>USA_Northwest-Arkansas-Airborne-Survey-2019-2020_GeoreferencedRaster_ShadedTMF.tif</enttypl>
#
#
# 				<enttypd>3-band raster geospatial data file of the aeromagnetic data Total Magnetic Field with shading.</enttypd>
#
#
# 				<enttypds>U.S. Geological Survey</enttypds>
#
#
# 			</enttyp>
#
#
# 			<attr>
#
#
# 				<attrlabl>Value</attrlabl>
#
#
# 				<attrdef>Unique numeric values contained in each raster cell.</attrdef>
#
#
# 				<attrdefs>U.S. Geological Survey</attrdefs>
#
#
# 				<attrdomv>
#
#
# 					<rdom>
#
#
# 						<rdommin>0</rdommin>
#
#
# 						<rdommax>255</rdommax>
#
#
# 					</rdom>
#
#
# 				</attrdomv>
#
#
# 			</attr>
#
#
# 		</detailed>
#
#
# 		<detailed>
#
#
# 			<enttyp>
#
#
# 				<enttypl>USA_Northwest-Arkansas-Airborne-Survey-2019-2020_GeoreferencedRaster_ShadedTMFI.tif</enttypl>
#
#
# 				<enttypd>3-band raster geospatial data file of the aeromagnetic data Total Magnetic Field Intensity with shading.</enttypd>
#
#
# 				<enttypds>U.S. Geological Survey</enttypds>
#
#
# 			</enttyp>
#
#
# 			<attr>
#
#
# 				<attrlabl>Value</attrlabl>
#
#
# 				<attrdef>Unique numeric values contained in each raster cell.</attrdef>
#
#
# 				<attrdefs>U.S. Geological Survey</attrdefs>
#
#
# 				<attrdomv>
#
#
# 					<rdom>
#
#
# 						<rdommin>0</rdommin>
#
#
# 						<rdommax>255</rdommax>
#
#
# 					</rdom>
#
#
# 				</attrdomv>
#
#
# 			</attr>
#
#
# 		</detailed>
#
#
# 		<detailed>
#
#
# 			<enttyp>
#
#
# 				<enttypl>USA_Northwest-Arkansas-Airborne-Survey-2019-2020_GeoreferencedRaster_TMFI.tif</enttypl>
#
#
# 				<enttypd>3-band raster geospatial data file of the aeromagnetic data of the Total Magnetic Field Intensity.</enttypd>
#
#
# 				<enttypds>U.S. Geological Survey</enttypds>
#
#
# 			</enttyp>
#
#
# 			<attr>
#
#
# 				<attrlabl>Value</attrlabl>
#
#
# 				<attrdef>Unique numeric values contained in each raster cell.</attrdef>
#
#
# 				<attrdefs>U.S. Geological Survey</attrdefs>
#
#
# 				<attrdomv>
#
#
# 					<rdom>
#
#
# 						<rdommin>0</rdommin>
#
#
# 						<rdommax>255</rdommax>
#
#
# 					</rdom>
#
#
# 				</attrdomv>
#
#
# 			</attr>
#
#
# 		</detailed>
#
#
# 		<detailed>
#
#
# 			<enttyp>
#
#
# 				<enttypl>USA_Northwest-Arkansas-Airborne-Survey-2019-2020_GeoreferencedRaster_VerticalMagneticGradientShaded.tif</enttypl>
#
#
# 				<enttypd>3-band raster geospatial data file of the aeromagnetic data of the Vertical Magnetic Gradient with shading.</enttypd>
#
#
# 				<enttypds>U.S. Geological Survey</enttypds>
#
#
# 			</enttyp>
#
#
# 			<attr>
#
#
# 				<attrlabl>Value</attrlabl>
#
#
# 				<attrdef>Unique numeric values contained in each raster cell.</attrdef>
#
#
# 				<attrdefs>U.S. Geological Survey</attrdefs>
#
#
# 				<attrdomv>
#
#
# 					<rdom>
#
#
# 						<rdommin>0</rdommin>
#
#
# 						<rdommax>255</rdommax>
#
#
# 					</rdom>
#
#
# 				</attrdomv>
#
#
# 			</attr>
#
#
# 		</detailed>
#
#
# 		<overview>
#
#
# 			<eaover>USA_Northwest-Arkansas-Airborne-Survey-2019-2020_Raster_TMFIShaded.png is a Portable Network Graphics (PNG) image of the Total Magnetic Field Intensity with shading.</eaover>
#
#
# 			<eadetcit>https://doi.org/10.5066/P91O2Y8W</eadetcit>
#
#
# 		</overview>
#
#
# 	</eainfo>
#
#
# 	<distinfo>
#
#
# 		<distrib>
#
#
# 			<cntinfo>
#
#
# 				<cntorgp>
#
#
# 					<cntorg>ScienceBase</cntorg>
#
#
# 					<cntper>U.S. Geological Survey</cntper>
#
#
# 				</cntorgp>
#
#
# 				<cntaddr>
#
#
# 					<addrtype>mailing and physical</addrtype>
#
#
# 					<address>Denver Federal Center, Building 810, Mail Stop 302</address>
#
#
# 					<city>Denver</city>
#
#
# 					<state>CO</state>
#
#
# 					<postal>80225</postal>
#
#
# 					<country>USA</country>
#
#
# 				</cntaddr>
#
#
# 				<cntvoice>1-888-275-8747</cntvoice>
#
#
# 				<cntemail>sciencebase@usgs.gov</cntemail>
#
#
# 			</cntinfo>
#
#
# 		</distrib>
#
#
# 		<resdesc>https://www.sciencebase.gov/catalog/item/5f066e2682ce21d4c3f90237</resdesc>
#
#
# 		<distliab>Unless otherwise stated, all data, metadata and related materials are considered to satisfy the quality standards relative to the purpose for which the data were collected. Although these data and associated metadata have been reviewed for accuracy and completeness and approved for release by the U.S. Geological Survey (USGS), no warranty expressed or implied is made regarding the display or utility of the data on any other system or for general or scientific purposes, nor shall the act of distribution constitute any such warranty.</distliab>
#
#
# 		<stdorder>
#
#
# 			<digform>
#
#
# 				<digtinfo>
#
#
# 					<formname>comma-delimited text</formname>
#
#
# 					<formvern>1</formvern>
#
#
# 					<formspec>USA_Northwest-Arkansas-Airborne-Survey-2019-2020_MagneticData.csv</formspec>
#
#
# 					<formcont>Comma Seperated Values (CSV) ASCII tabular data file containing attribute information associated with the data set.</formcont>
#
#
# 					<filedec>No compression applied</filedec>
#
#
# 					<transize>4844.078276</transize>
#
#
# 				</digtinfo>
#
#
# 				<digtopt>
#
#
# 					<onlinopt>
#
#
# 						<computer>
#
#
# 							<networka>
#
#
# 								<networkr>https://www.sciencebase.gov/catalog/item/requestDownload/5f066e2682ce21d4c3f90237?filePath=__disk__cc%2F4b%2F74%2Fcc4b74b648e130ab6b71b1801f918b4e14e8ff03</networkr>
#
#
# 							</networka>
#
#
# 						</computer>
#
#
# 					</onlinopt>
#
#
# 				</digtopt>
#
#
# 			</digform>
#
#
# 			<digform>
#
#
# 				<digtinfo>
#
#
# 					<formname>PNG</formname>
#
#
# 					<formvern>1</formvern>
#
#
# 					<formspec>USA_Northwest-Arkansas-Airborne-Survey-2019-2020_Raster_TMFIShaded.png</formspec>
#
#
# 					<formcont>Portable Network Graphics (PNG) raster image associated with the data set.</formcont>
#
#
# 					<filedec>No compression applied</filedec>
#
#
# 					<transize>0.255597</transize>
#
#
# 				</digtinfo>
#
#
# 				<digtopt>
#
#
# 					<onlinopt>
#
#
# 						<computer>
#
#
# 							<networka>
#
#
# 								<networkr>https://www.sciencebase.gov/catalog/file/get/5f066e2682ce21d4c3f90237?f=__disk__27%2F8b%2F76%2F278b76bf8027e39931171178ca23cbd9329a123a</networkr>
#
#
# 							</networka>
#
#
# 						</computer>
#
#
# 					</onlinopt>
#
#
# 				</digtopt>
#
#
# 			</digform>
#
#
# 			<fees>none</fees>
#
#
# 		</stdorder>
#
#
# 	</distinfo>
#
#
# 	<metainfo>
#
#
# 		<metd>20200929</metd>
#
#
# 		<metc>
#
#
# 			<cntinfo>
#
#
# 				<cntperp>
#
#
# 					<cntper>Philip Brown</cntper>
#
#
# 					<cntorg>U.S. Geological Survey</cntorg>
#
#
# 				</cntperp>
#
#
# 				<cntpos>Geophysicist</cntpos>
#
#
# 				<cntaddr>
#
#
# 					<addrtype>mailing and physical</addrtype>
#
#
# 					<address>PO Box 25046, Mail Stop 973, Bldg 20, Denver Federal Center, W 6th Ave and Kipling St</address>
#
#
# 					<city>Denver</city>
#
#
# 					<state>CO</state>
#
#
# 					<postal>80225-0046</postal>
#
#
# 					<country>US</country>
#
#
# 				</cntaddr>
#
#
# 				<cntvoice>303-236-1310</cntvoice>
#
#
# 				<cntemail>pbrown@usgs.gov</cntemail>
#
#
# 			</cntinfo>
#
#
# 		</metc>
#
#
# 		<metstdn>FGDC Content Standard for Digital Geospatial Metadata</metstdn>
#
#
# 		<metstdv>FGDC-STD-001-1998</metstdv>
#
#
# 	</metainfo>
#
#
# </metadata>

# %% [markdown]
# ### 4)	Perform quality checks on metadata:
# ##### a.	The metadata matches the data and its correct version (e.g., is this metadata record describing the correct dataset? Sometimes existing metadata records are used as templates and some old information carries over to the new record:

# %%
#login to ScienceBase
sb = pysb.SbSession()
username = input("Username:  ")
sb.loginc(str(username))
#Check to see if login is successful
sb.is_logged_in()
#Get the ScienceBase Login session info
sb.get_session_info()
# Out:
# Username:  pbrown@usgs.gov
# ········
# {'fullDisplayName': 'Philip J Brown II [pbrown@usgs.gov]',
#  'isLoggedIn': True,
#  'jossoSessionId': 'A4AE9EEE44F7C2A58BA02FE04A723DEF',
#  'displayName': 'Philip J Brown II',
#  'email': 'pbrown@usgs.gov',
#  'username': 'pbrown@usgs.gov'}

# %%
# Now lets get the item - be sure to use the correct catalog number!!!
catNum = '5f066e2682ce21d4c3f90237'
item_json = sb.get_item(catNum)
#print ("Public Item: \n\t" + str(item_json))
print(json.dumps(item_json, indent=2, sort_keys=True))
# Out:
# {
#   "body": "This publication provides digital flight line data for a high-resolution magnetic survey over an area of northwest Arkansas. The airborne geophysical survey was jointly funded by the USGS National Cooperative Geologic Mapping Program and the Earth Mapping Resource Initiative and was designed to meet the complimentary needs related to geologic mapping and mineral resource research. The survey covers an irregular area 225 by 110 kilometers over the transition between the Ouachita and Ozarks Plateau physiographic provinces and includes 67,614 line-kilometers of magnetic data. Data were collected from a fixed-wing aircraft flown at mean terrain clearance of 167 meters above topography along N-S flight lines spaced at 200 meter intervals. Tie lines were flown in an E-W direction every 3000 meters. Data were collected by EON Geosciences under contract with the USGS using a fixed wing aircraft with a magnetometer mounted in the tail stinger. The survey operated out of the Branson, Missouri airport from October of 2019 to March of 2020. Files that are available in this child item include flight line data for the magnetic survey.",
#   "browseCategories": [
#     "Data"
#   ],
#   "browseTypes": [
#     "Raster",
#     "GeoTIFF",
#     "Downloadable",
#     "Map Service"
#   ],
#   "citation": "McCafferty, A.E., and Brown, P.J., 2020, Airborne magnetic and radiometric survey over northwest Arkansas, 2019-2020: U.S. Geological Survey data release, https://doi.org/10.5066/P91O2Y8W.",
#   "contacts": [
#     {
#       "active": true,
#       "contactType": "person",
#       "email": "anne@usgs.gov",
#       "firstName": "Anne",
#       "jobTitle": "Research Geophysicist",
#       "lastName": "McCafferty",
#       "middleName": "E",
#       "name": "Anne E McCafferty",
#       "oldPartyId": 6653,
#       "onlineResource": "https://usgs.gov/staff-profiles/anne-e-mccafferty",
#       "organization": {
#         "displayText": "Geology, Geophysics, and Geochemistry Science Center"
#       },
#       "personalTitle": "Ms.",
#       "primaryLocation": {
#         "buildingCode": "KAC",
#         "faxPhone": "3032361425",
#         "mailAddress": {},
#         "name": "Anne E McCafferty/GD/USGS/DOI - Primary Location",
#         "officePhone": "3032361397",
#         "streetAddress": {
#           "city": "Lakewood",
#           "country": "US",
#           "line1": "W 6th Ave Kipling St",
#           "state": "CO",
#           "zip": "80225"
#         }
#       },
#       "type": "Point of Contact"
#     },
#     {
#       "active": true,
#       "contactType": "person",
#       "email": "anne@usgs.gov",
#       "firstName": "Anne",
#       "jobTitle": "Research Geophysicist",
#       "lastName": "McCafferty",
#       "middleName": "E",
#       "name": "Anne E McCafferty",
#       "oldPartyId": 6653,
#       "onlineResource": "https://usgs.gov/staff-profiles/anne-e-mccafferty",
#       "organization": {
#         "displayText": "Geology, Geophysics, and Geochemistry Science Center"
#       },
#       "personalTitle": "Ms.",
#       "primaryLocation": {
#         "buildingCode": "KAC",
#         "faxPhone": "3032361425",
#         "mailAddress": {},
#         "name": "Anne E McCafferty/GD/USGS/DOI - Primary Location",
#         "officePhone": "3032361397",
#         "streetAddress": {
#           "city": "Lakewood",
#           "country": "US",
#           "line1": "W 6th Ave Kipling St",
#           "state": "CO",
#           "zip": "80225"
#         }
#       },
#       "type": "Originator"
#     },
#     {
#       "active": true,
#       "contactType": "person",
#       "email": "pbrown@usgs.gov",
#       "firstName": "Philip",
#       "jobTitle": "Geophysicist",
#       "lastName": "Brown II",
#       "middleName": "J",
#       "name": "Philip J Brown II",
#       "oldPartyId": 1233,
#       "onlineResource": "https://usgs.gov/staff-profiles/philip-j-brown",
#       "orcId": "0000-0002-2415-7462",
#       "organization": {
#         "displayText": "Geology, Geophysics, and Geochemistry Science Center"
#       },
#       "primaryLocation": {
#         "buildingCode": "KAC",
#         "faxPhone": "3032361425",
#         "mailAddress": {},
#         "name": "Philip J Brown II/GD/USGS/DOI - Primary Location",
#         "officePhone": "3032361310",
#         "streetAddress": {
#           "city": "Lakewood",
#           "country": "US",
#           "line1": "W 6th Ave Kipling St",
#           "state": "CO",
#           "zip": "80225"
#         }
#       },
#       "type": "Originator"
#     },
#     {
#       "active": true,
#       "contactType": "person",
#       "email": "pbrown@usgs.gov",
#       "firstName": "Philip",
#       "jobTitle": "Geophysicist",
#       "lastName": "Brown II",
#       "middleName": "J",
#       "name": "Philip J Brown II",
#       "oldPartyId": 1233,
#       "onlineResource": "https://usgs.gov/staff-profiles/philip-j-brown",
#       "orcId": "0000-0002-2415-7462",
#       "organization": {
#         "displayText": "Geology, Geophysics, and Geochemistry Science Center"
#       },
#       "primaryLocation": {
#         "buildingCode": "KAC",
#         "faxPhone": "3032361425",
#         "mailAddress": {},
#         "name": "Philip J Brown II/GD/USGS/DOI - Primary Location",
#         "officePhone": "3032361310",
#         "streetAddress": {
#           "city": "Lakewood",
#           "country": "US",
#           "line1": "W 6th Ave Kipling St",
#           "state": "CO",
#           "zip": "80225"
#         }
#       },
#       "type": "Metadata Contact"
#     },
#     {
#       "active": true,
#       "aliases": [
#         "{\"name\":\"Geological Survey (U.S.)\"}",
#         "{\"name\":\"USGS\"}",
#         "{\"name\":\"U.S. GEOLOGICAL SURVEY\"}"
#       ],
#       "contactType": "organization",
#       "fbmsCodes": [
#         "GG00000000"
#       ],
#       "logoUrl": "http://my.usgs.gov/static-cache/images/dataOwner/v1/logosMed/USGSLogo.gif",
#       "name": "U.S. Geological Survey",
#       "oldPartyId": 18139,
#       "onlineResource": "http://www.usgs.gov/",
#       "organization": {},
#       "primaryLocation": {
#         "mailAddress": {},
#         "name": "U.S. Geological Survey - Location",
#         "streetAddress": {}
#       },
#       "smallLogoUrl": "http://my.usgs.gov/static-cache/images/dataOwner/v1/logosSmall/USGSLogo.gif",
#       "type": "Publisher"
#     },
#     {
#       "aliases": [
#         "{\"name\":\"GGGSC\"}"
#       ],
#       "contactType": "organization",
#       "name": "Geology, Geophysics, and Geochemistry Science Center",
#       "oldPartyId": 76255,
#       "organization": {},
#       "primaryLocation": {
#         "mailAddress": {},
#         "name": "Geology, Geophysics, and Geochemistry Science Center - Location",
#         "streetAddress": {}
#       },
#       "type": "SDC Data Owner"
#     },
#     {
#       "active": true,
#       "contactType": "organization",
#       "name": "Energy and Minerals",
#       "oldPartyId": 64232,
#       "organization": {},
#       "primaryLocation": {
#         "mailAddress": {},
#         "name": "Energy and Minerals Mission Area - Location",
#         "streetAddress": {}
#       },
#       "type": "USGS Mission Area"
#     },
#     {
#       "contactType": "organization",
#       "email": "sciencebase@usgs.gov",
#       "name": "U.S. Geological Survey - ScienceBase",
#       "oldPartyId": 70157,
#       "onlineResource": "https://www.sciencebase.gov",
#       "organization": {},
#       "primaryLocation": {
#         "mailAddress": {
#           "city": "Denver",
#           "country": "United States",
#           "line1": "Denver Federal Center",
#           "line2": "Building 810",
#           "mailStopCode": "302",
#           "state": "CO",
#           "zip": "80225"
#         },
#         "name": "U.S. Geological Survey - ScienceBase - Location",
#         "officePhone": "18882758747",
#         "streetAddress": {}
#       },
#       "type": "Distributor"
#     }
#   ],
#   "dates": [
#     {
#       "dateString": "2020-09-29",
#       "label": "Publication Date",
#       "type": "Publication"
#     },
#     {
#       "dateString": "2019-10-05",
#       "label": "",
#       "type": "Start"
#     },
#     {
#       "dateString": "2020-03-07",
#       "label": "",
#       "type": "End"
#     }
#   ],
#   "distributionLinks": [
#     {
#       "files": "",
#       "name": "",
#       "rel": "alternate",
#       "title": "KML Service",
#       "type": "kml",
#       "typeLabel": "KML Download",
#       "uri": "https://www.sciencebase.gov/catalogMaps/mapping/ows/5f066e2682ce21d4c3f90237?mode=download&request=kml&service=wms&layers=USA_Northwest-Arkansas-Airborne-Survey-2019-2020_GeoreferencedRaster_VerticalMagneticGradientShaded"
#     },
#     {
#       "files": "",
#       "name": "",
#       "rel": "alternate",
#       "title": "ScienceBase WMS Service",
#       "type": "serviceCapabilitiesUrl",
#       "typeLabel": "OGC Service Capabilities URL",
#       "uri": "https://www.sciencebase.gov/catalogMaps/mapping/ows/5f066e2682ce21d4c3f90237?service=wms&request=getcapabilities&version=1.3.0"
#     },
#     {
#       "files": "",
#       "name": "",
#       "rel": "alternate",
#       "title": "ScienceBase WCS Service",
#       "type": "serviceCapabilitiesUrl",
#       "typeLabel": "OGC Service Capabilities URL",
#       "uri": "https://www.sciencebase.gov/catalogMaps/mapping/ows/5f066e2682ce21d4c3f90237?service=wcs&request=getcapabilities&version=1.0.0"
#     },
#     {
#       "files": [
#         {
#           "contentType": "image/geotiff",
#           "name": "USA_Northwest-Arkansas-Airborne-Survey-2019-2020_GeoreferencedRaster_TMFI/USA_Northwest-Arkansas-Airborne-Survey-2019-2020_GeoreferencedRaster_TMFI.tif",
#           "size": 4126126,
#           "title": ""
#         },
#         {
#           "contentType": "application/x-tika-msoffice",
#           "name": "USA_Northwest-Arkansas-Airborne-Survey-2019-2020_GeoreferencedRaster_TMFI/USA_Northwest-Arkansas-Airborne-Survey-2019-2020_GeoreferencedRaster_TMFI.tif.gi",
#           "size": 11776,
#           "title": ""
#         },
#         {
#           "contentType": "application/x-tika-msoffice",
#           "name": "USA_Northwest-Arkansas-Airborne-Survey-2019-2020_GeoreferencedRaster_ShadedTMF/USA_Northwest-Arkansas-Airborne-Survey-2019-2020_GeoreferencedRaster_ShadedTMF.tif.gi",
#           "size": 11776,
#           "title": ""
#         },
#         {
#           "contentType": "image/geotiff",
#           "name": "USA_Northwest-Arkansas-Airborne-Survey-2019-2020_GeoreferencedRaster_ShadedTMF/USA_Northwest-Arkansas-Airborne-Survey-2019-2020_GeoreferencedRaster_ShadedTMF.tif",
#           "size": 4123560,
#           "title": ""
#         },
#         {
#           "contentType": "application/x-tika-msoffice",
#           "name": "USA_Northwest-Arkansas-Airborne-Survey-2019-2020_GeoreferencedRaster_ShadedTMFI/USA_Northwest-Arkansas-Airborne-Survey-2019-2020_GeoreferencedRaster_ShadedTMFI.tif.gi",
#           "size": 11776,
#           "title": ""
#         },
#         {
#           "contentType": "image/geotiff",
#           "name": "USA_Northwest-Arkansas-Airborne-Survey-2019-2020_GeoreferencedRaster_ShadedTMFI/USA_Northwest-Arkansas-Airborne-Survey-2019-2020_GeoreferencedRaster_ShadedTMFI.tif",
#           "size": 4241540,
#           "title": ""
#         },
#         {
#           "contentType": "image/geotiff",
#           "name": "USA_Northwest-Arkansas-Airborne-Survey-2019-2020_GeoreferencedRaster_VerticalMagneticGradientShaded/USA_Northwest-Arkansas-Airborne-Survey-2019-2020_GeoreferencedRaster_VerticalMagneticGradientShaded.tif",
#           "size": 4111488,
#           "title": ""
#         },
#         {
#           "contentType": "application/x-tika-msoffice",
#           "name": "USA_Northwest-Arkansas-Airborne-Survey-2019-2020_GeoreferencedRaster_VerticalMagneticGradientShaded/USA_Northwest-Arkansas-Airborne-Survey-2019-2020_GeoreferencedRaster_VerticalMagneticGradientShaded.tif.gi",
#           "size": 11776,
#           "title": ""
#         },
#         {
#           "contentType": "text/csv",
#           "name": "USA_Northwest-Arkansas-Airborne-Survey-2019-2020_MagneticData.csv",
#           "size": 4844078276,
#           "title": ""
#         },
#         {
#           "contentType": "image/png",
#           "name": "USA_Northwest-Arkansas-Airborne-Survey-2019-2020_Raster_TMFIShaded.png",
#           "size": 255597,
#           "title": ""
#         },
#         {
#           "contentType": "application/fgdc+xml",
#           "name": "USA_Northwest-Arkansas-Airborne-Survey-2019-2020_Magnetic.xml",
#           "size": 35909,
#           "title": ""
#         }
#       ],
#       "name": "Airbornemagneti.zip",
#       "rel": "alternate",
#       "title": "Download Attached Files",
#       "type": "downloadLink",
#       "typeLabel": "Download Link",
#       "uri": "https://www.sciencebase.gov/catalog/file/get/5f066e2682ce21d4c3f90237"
#     }
#   ],
#   "facets": [
#     {
#       "boundingBox": {
#         "maxX": -91.31287168905195,
#         "maxY": 36.51007331662858,
#         "minX": -93.83156011065195,
#         "minY": 35.50218740382857
#       },
#       "className": "gov.sciencebase.catalog.item.facet.RasterFacet",
#       "facetName": "Raster",
#       "files": [
#         {
#           "bucket": null,
#           "checksum": {
#             "type": "MD5",
#             "value": "5aade5394d825602da3b1243ec1be0d2"
#           },
#           "contentEncoding": null,
#           "contentType": "image/geotiff",
#           "cuid": null,
#           "dateUploaded": "2020-07-09T23:04:12Z",
#           "downloadUri": "https://www.sciencebase.gov/catalog/file/get/5f066e2682ce21d4c3f90237?f=__disk__51%2F08%2F12%2F510812e728e9c9e625ac6e07ca7bde5e51820381",
#           "imageHeight": null,
#           "imageWidth": null,
#           "key": null,
#           "name": "USA_Northwest-Arkansas-Airborne-Survey-2019-2020_GeoreferencedRaster_TMFI.tif",
#           "node": null,
#           "originalMetadata": false,
#           "pathOnDisk": "__disk__51/08/12/510812e728e9c9e625ac6e07ca7bde5e51820381",
#           "processToken": null,
#           "processed": false,
#           "published": null,
#           "s3Object": null,
#           "size": 4126126,
#           "title": "",
#           "uploadedBy": "pbrown@usgs.gov",
#           "url": "https://www.sciencebase.gov/catalog/file/get/5f066e2682ce21d4c3f90237?f=__disk__51%2F08%2F12%2F510812e728e9c9e625ac6e07ca7bde5e51820381",
#           "useForPreview": false
#         },
#         {
#           "bucket": null,
#           "checksum": {
#             "type": "MD5",
#             "value": "98d0f20b2580ab65d8f6ca38351db241"
#           },
#           "contentEncoding": null,
#           "contentType": "application/x-tika-msoffice",
#           "cuid": null,
#           "dateUploaded": "2020-07-09T23:04:01Z",
#           "downloadUri": "https://www.sciencebase.gov/catalog/file/get/5f066e2682ce21d4c3f90237?f=__disk__f0%2F14%2F6a%2Ff0146a25497aef1e66062ce315095a2a99d10747",
#           "imageHeight": null,
#           "imageWidth": null,
#           "key": null,
#           "name": "USA_Northwest-Arkansas-Airborne-Survey-2019-2020_GeoreferencedRaster_TMFI.tif.gi",
#           "node": null,
#           "originalMetadata": false,
#           "pathOnDisk": "__disk__f0/14/6a/f0146a25497aef1e66062ce315095a2a99d10747",
#           "processToken": null,
#           "processed": false,
#           "published": null,
#           "s3Object": null,
#           "size": 11776,
#           "title": "",
#           "uploadedBy": "pbrown@usgs.gov",
#           "url": "https://www.sciencebase.gov/catalog/file/get/5f066e2682ce21d4c3f90237?f=__disk__f0%2F14%2F6a%2Ff0146a25497aef1e66062ce315095a2a99d10747",
#           "useForPreview": false
#         }
#       ],
#       "name": "USA_Northwest-Arkansas-Airborne-Survey-2019-2020_GeoreferencedRaster_TMFI",
#       "nativeCrs": "EPSG:4326",
#       "rasterType": "GeoTIFF"
#     },
#     {
#       "boundingBox": {
#         "maxX": -91.31287168040883,
#         "maxY": 36.51007332008724,
#         "minX": -93.83156011065195,
#         "minY": 35.50218740382858
#       },
#       "className": "gov.sciencebase.catalog.item.facet.RasterFacet",
#       "facetName": "Raster",
#       "files": [
#         {
#           "bucket": null,
#           "checksum": {
#             "type": "MD5",
#             "value": "5f6551b3f058be43cb2e2491d9b72ef4"
#           },
#           "contentEncoding": null,
#           "contentType": "application/x-tika-msoffice",
#           "cuid": null,
#           "dateUploaded": "2020-07-09T23:13:48Z",
#           "downloadUri": "https://www.sciencebase.gov/catalog/file/get/5f066e2682ce21d4c3f90237?f=__disk__8e%2Fbc%2Fca%2F8ebccad944d613ed58609ada31e04ac6d6f5671e",
#           "imageHeight": null,
#           "imageWidth": null,
#           "key": null,
#           "name": "USA_Northwest-Arkansas-Airborne-Survey-2019-2020_GeoreferencedRaster_ShadedTMF.tif.gi",
#           "node": null,
#           "originalMetadata": false,
#           "pathOnDisk": "__disk__8e/bc/ca/8ebccad944d613ed58609ada31e04ac6d6f5671e",
#           "processToken": null,
#           "processed": false,
#           "published": null,
#           "s3Object": null,
#           "size": 11776,
#           "title": "",
#           "uploadedBy": "pbrown@usgs.gov",
#           "url": "https://www.sciencebase.gov/catalog/file/get/5f066e2682ce21d4c3f90237?f=__disk__8e%2Fbc%2Fca%2F8ebccad944d613ed58609ada31e04ac6d6f5671e",
#           "useForPreview": false
#         },
#         {
#           "bucket": null,
#           "checksum": {
#             "type": "MD5",
#             "value": "2bcbf2a094b81c465b053fb07ba7407d"
#           },
#           "contentEncoding": null,
#           "contentType": "image/geotiff",
#           "cuid": null,
#           "dateUploaded": "2020-07-09T23:13:53Z",
#           "downloadUri": "https://www.sciencebase.gov/catalog/file/get/5f066e2682ce21d4c3f90237?f=__disk__97%2Fec%2F1a%2F97ec1a52d0483cf3793c87210c0871bd1c44f4b1",
#           "imageHeight": null,
#           "imageWidth": null,
#           "key": null,
#           "name": "USA_Northwest-Arkansas-Airborne-Survey-2019-2020_GeoreferencedRaster_ShadedTMF.tif",
#           "node": null,
#           "originalMetadata": false,
#           "pathOnDisk": "__disk__97/ec/1a/97ec1a52d0483cf3793c87210c0871bd1c44f4b1",
#           "processToken": null,
#           "processed": false,
#           "published": null,
#           "s3Object": null,
#           "size": 4123560,
#           "title": "",
#           "uploadedBy": "pbrown@usgs.gov",
#           "url": "https://www.sciencebase.gov/catalog/file/get/5f066e2682ce21d4c3f90237?f=__disk__97%2Fec%2F1a%2F97ec1a52d0483cf3793c87210c0871bd1c44f4b1",
#           "useForPreview": false
#         }
#       ],
#       "name": "USA_Northwest-Arkansas-Airborne-Survey-2019-2020_GeoreferencedRaster_ShadedTMF",
#       "nativeCrs": "EPSG:4326",
#       "rasterType": "GeoTIFF"
#     },
#     {
#       "boundingBox": {
#         "maxX": -91.30010076632468,
#         "maxY": 36.51072080660856,
#         "minX": -93.83156011065195,
#         "minY": 35.50218740382857
#       },
#       "className": "gov.sciencebase.catalog.item.facet.RasterFacet",
#       "facetName": "Raster",
#       "files": [
#         {
#           "bucket": null,
#           "checksum": {
#             "type": "MD5",
#             "value": "c346b682279a4f0c354af4820de630f9"
#           },
#           "contentEncoding": null,
#           "contentType": "application/x-tika-msoffice",
#           "cuid": null,
#           "dateUploaded": "2020-07-09T23:15:22Z",
#           "downloadUri": "https://www.sciencebase.gov/catalog/file/get/5f066e2682ce21d4c3f90237?f=__disk__26%2F9b%2Ffc%2F269bfc463f6d038dcdbfff08dc08dc9d76650be5",
#           "imageHeight": null,
#           "imageWidth": null,
#           "key": null,
#           "name": "USA_Northwest-Arkansas-Airborne-Survey-2019-2020_GeoreferencedRaster_ShadedTMFI.tif.gi",
#           "node": null,
#           "originalMetadata": false,
#           "pathOnDisk": "__disk__26/9b/fc/269bfc463f6d038dcdbfff08dc08dc9d76650be5",
#           "processToken": null,
#           "processed": false,
#           "published": null,
#           "s3Object": null,
#           "size": 11776,
#           "title": "",
#           "uploadedBy": "pbrown@usgs.gov",
#           "url": "https://www.sciencebase.gov/catalog/file/get/5f066e2682ce21d4c3f90237?f=__disk__26%2F9b%2Ffc%2F269bfc463f6d038dcdbfff08dc08dc9d76650be5",
#           "useForPreview": false
#         },
#         {
#           "bucket": null,
#           "checksum": {
#             "type": "MD5",
#             "value": "ab19b55088d1147fcfa114aa5b316c36"
#           },
#           "contentEncoding": null,
#           "contentType": "image/geotiff",
#           "cuid": null,
#           "dateUploaded": "2020-07-09T23:15:28Z",
#           "downloadUri": "https://www.sciencebase.gov/catalog/file/get/5f066e2682ce21d4c3f90237?f=__disk__7b%2F1e%2Ffe%2F7b1efed166d6a3fe3dbaec9c75cff9b4a6779b87",
#           "imageHeight": null,
#           "imageWidth": null,
#           "key": null,
#           "name": "USA_Northwest-Arkansas-Airborne-Survey-2019-2020_GeoreferencedRaster_ShadedTMFI.tif",
#           "node": null,
#           "originalMetadata": false,
#           "pathOnDisk": "__disk__7b/1e/fe/7b1efed166d6a3fe3dbaec9c75cff9b4a6779b87",
#           "processToken": null,
#           "processed": false,
#           "published": null,
#           "s3Object": null,
#           "size": 4241540,
#           "title": "",
#           "uploadedBy": "pbrown@usgs.gov",
#           "url": "https://www.sciencebase.gov/catalog/file/get/5f066e2682ce21d4c3f90237?f=__disk__7b%2F1e%2Ffe%2F7b1efed166d6a3fe3dbaec9c75cff9b4a6779b87",
#           "useForPreview": false
#         }
#       ],
#       "name": "USA_Northwest-Arkansas-Airborne-Survey-2019-2020_GeoreferencedRaster_ShadedTMFI",
#       "nativeCrs": "EPSG:4326",
#       "rasterType": "GeoTIFF"
#     },
#     {
#       "boundingBox": {
#         "maxX": -91.31287168040883,
#         "maxY": 36.51007332008724,
#         "minX": -93.83156011065195,
#         "minY": 35.50218740382858
#       },
#       "className": "gov.sciencebase.catalog.item.facet.RasterFacet",
#       "facetName": "Raster",
#       "files": [
#         {
#           "bucket": null,
#           "checksum": {
#             "type": "MD5",
#             "value": "162087ad3e02aa7bc6b4bd70e07110e5"
#           },
#           "contentEncoding": null,
#           "contentType": "image/geotiff",
#           "cuid": null,
#           "dateUploaded": "2020-07-09T23:16:00Z",
#           "downloadUri": "https://www.sciencebase.gov/catalog/file/get/5f066e2682ce21d4c3f90237?f=__disk__87%2Fa1%2Fdf%2F87a1df63df884a06a0c1a606a6a9ffd2921a9af9",
#           "imageHeight": null,
#           "imageWidth": null,
#           "key": null,
#           "name": "USA_Northwest-Arkansas-Airborne-Survey-2019-2020_GeoreferencedRaster_VerticalMagneticGradientShaded.tif",
#           "node": null,
#           "originalMetadata": false,
#           "pathOnDisk": "__disk__87/a1/df/87a1df63df884a06a0c1a606a6a9ffd2921a9af9",
#           "processToken": null,
#           "processed": false,
#           "published": null,
#           "s3Object": null,
#           "size": 4111488,
#           "title": "",
#           "uploadedBy": "pbrown@usgs.gov",
#           "url": "https://www.sciencebase.gov/catalog/file/get/5f066e2682ce21d4c3f90237?f=__disk__87%2Fa1%2Fdf%2F87a1df63df884a06a0c1a606a6a9ffd2921a9af9",
#           "useForPreview": false
#         },
#         {
#           "bucket": null,
#           "checksum": {
#             "type": "MD5",
#             "value": "358c21ecf179fba1d55183b32db74b0b"
#           },
#           "contentEncoding": null,
#           "contentType": "application/x-tika-msoffice",
#           "cuid": null,
#           "dateUploaded": "2020-07-09T23:15:56Z",
#           "downloadUri": "https://www.sciencebase.gov/catalog/file/get/5f066e2682ce21d4c3f90237?f=__disk__7d%2F46%2F87%2F7d46870e760e95b510be71a881cad025cc9ce49b",
#           "imageHeight": null,
#           "imageWidth": null,
#           "key": null,
#           "name": "USA_Northwest-Arkansas-Airborne-Survey-2019-2020_GeoreferencedRaster_VerticalMagneticGradientShaded.tif.gi",
#           "node": null,
#           "originalMetadata": false,
#           "pathOnDisk": "__disk__7d/46/87/7d46870e760e95b510be71a881cad025cc9ce49b",
#           "processToken": null,
#           "processed": false,
#           "published": null,
#           "s3Object": null,
#           "size": 11776,
#           "title": "",
#           "uploadedBy": "pbrown@usgs.gov",
#           "url": "https://www.sciencebase.gov/catalog/file/get/5f066e2682ce21d4c3f90237?f=__disk__7d%2F46%2F87%2F7d46870e760e95b510be71a881cad025cc9ce49b",
#           "useForPreview": false
#         }
#       ],
#       "name": "USA_Northwest-Arkansas-Airborne-Survey-2019-2020_GeoreferencedRaster_VerticalMagneticGradientShaded",
#       "nativeCrs": "EPSG:4326",
#       "rasterType": "GeoTIFF"
#     }
#   ],
#   "files": [
#     {
#       "bucket": null,
#       "checksum": {
#         "type": "MD5",
#         "value": "7177f59ba69fafc37640d1f64034d17a"
#       },
#       "contentEncoding": null,
#       "contentType": "text/csv",
#       "cuid": null,
#       "dateUploaded": "2020-07-09T02:20:40Z",
#       "downloadUri": "https://www.sciencebase.gov/catalog/file/get/5f066e2682ce21d4c3f90237?f=__disk__cc%2F4b%2F74%2Fcc4b74b648e130ab6b71b1801f918b4e14e8ff03",
#       "imageHeight": null,
#       "imageWidth": null,
#       "key": null,
#       "name": "USA_Northwest-Arkansas-Airborne-Survey-2019-2020_MagneticData.csv",
#       "node": null,
#       "originalMetadata": false,
#       "pathOnDisk": "__disk__cc/4b/74/cc4b74b648e130ab6b71b1801f918b4e14e8ff03",
#       "processToken": null,
#       "processed": false,
#       "published": false,
#       "s3DownloadRequestPageUri": "https://www.sciencebase.gov/catalog/item/requestDownload/5f066e2682ce21d4c3f90237?filePath=__disk__cc%2F4b%2F74%2Fcc4b74b648e130ab6b71b1801f918b4e14e8ff03",
#       "s3Object": {
#         "bucket": "prod-is-s3-service",
#         "contentType": "text/csv",
#         "dateUploaded": "2020-07-15T21:29:06Z",
#         "filePath": "5f066e2682ce21d4c3f90237/cc4b74b648e130ab6b71b1801f918b4e14e8ff03/USA_Northwest-Arkansas-Airborne-Survey-2019-2020_MagneticData.csv",
#         "name": "USA_Northwest-Arkansas-Airborne-Survey-2019-2020_MagneticData.csv",
#         "s3Source": null,
#         "s3SourceBucket": null,
#         "s3SourcePath": null,
#         "size": 4844078276,
#         "status": "Complete",
#         "title": "S3 bucket copy of file USA_Northwest-Arkansas-Airborne-Survey-2019-2020_MagneticData.csv",
#         "uploadedBy": "bdrenth@usgs.gov"
#       },
#       "size": 4844078276,
#       "title": "",
#       "uploadedBy": "pbrown@usgs.gov",
#       "url": "https://www.sciencebase.gov/catalog/file/get/5f066e2682ce21d4c3f90237?f=__disk__cc%2F4b%2F74%2Fcc4b74b648e130ab6b71b1801f918b4e14e8ff03",
#       "useForPreview": false
#     },
#     {
#       "bucket": null,
#       "checksum": {
#         "type": "MD5",
#         "value": "afd993a31bd6e2147f1ce1fe27f67859"
#       },
#       "contentEncoding": null,
#       "contentType": "image/png",
#       "cuid": null,
#       "dateUploaded": "2020-07-09T18:55:33Z",
#       "downloadUri": "https://www.sciencebase.gov/catalog/file/get/5f066e2682ce21d4c3f90237?f=__disk__27%2F8b%2F76%2F278b76bf8027e39931171178ca23cbd9329a123a",
#       "imageHeight": 760,
#       "imageWidth": 1059,
#       "key": null,
#       "name": "USA_Northwest-Arkansas-Airborne-Survey-2019-2020_Raster_TMFIShaded.png",
#       "node": null,
#       "originalMetadata": false,
#       "pathOnDisk": "__disk__27/8b/76/278b76bf8027e39931171178ca23cbd9329a123a",
#       "previewImage": {
#         "medium": {
#           "height": 416,
#           "uri": "https://www.sciencebase.gov/catalog/file/get/5f066e2682ce21d4c3f90237?f=__disk__27%2F8b%2F76%2F278b76bf8027e39931171178ca23cbd9329a123a&width=580&height=416",
#           "width": 580
#         },
#         "small": {
#           "height": 251,
#           "uri": "https://www.sciencebase.gov/catalog/file/get/5f066e2682ce21d4c3f90237?f=__disk__27%2F8b%2F76%2F278b76bf8027e39931171178ca23cbd9329a123a&width=350&height=251",
#           "width": 350
#         },
#         "thumbnail": {
#           "height": 108,
#           "uri": "https://www.sciencebase.gov/catalog/file/get/5f066e2682ce21d4c3f90237?f=__disk__27%2F8b%2F76%2F278b76bf8027e39931171178ca23cbd9329a123a&width=150&height=108",
#           "width": 150
#         }
#       },
#       "processToken": null,
#       "processed": false,
#       "published": null,
#       "s3Object": null,
#       "size": 255597,
#       "title": "",
#       "uploadedBy": "pbrown@usgs.gov",
#       "url": "https://www.sciencebase.gov/catalog/file/get/5f066e2682ce21d4c3f90237?f=__disk__27%2F8b%2F76%2F278b76bf8027e39931171178ca23cbd9329a123a",
#       "useForPreview": false,
#       "viewUri": "https://www.sciencebase.gov/catalog/file/get/5f066e2682ce21d4c3f90237?f=__disk__27%2F8b%2F76%2F278b76bf8027e39931171178ca23cbd9329a123a&width=1059&height=760"
#     },
#     {
#       "bucket": null,
#       "checksum": {
#         "type": "MD5",
#         "value": "c2f14a7a39e2e2552c18424054a4c8f7"
#       },
#       "contentEncoding": null,
#       "contentType": "application/fgdc+xml",
#       "cuid": null,
#       "dateUploaded": "2020-09-29T19:09:07Z",
#       "downloadUri": "https://www.sciencebase.gov/catalog/file/get/5f066e2682ce21d4c3f90237?f=__disk__63%2F64%2F80%2F63648082412369fa65285e35e8487e08f5db696c",
#       "imageHeight": null,
#       "imageWidth": null,
#       "key": null,
#       "metadataHtmlViewUri": "https://www.sciencebase.gov/catalog/file/get/5f066e2682ce21d4c3f90237?f=__disk__63%2F64%2F80%2F63648082412369fa65285e35e8487e08f5db696c&transform=1",
#       "name": "USA_Northwest-Arkansas-Airborne-Survey-2019-2020_Magnetic.xml",
#       "node": null,
#       "originalMetadata": true,
#       "pathOnDisk": "__disk__63/64/80/63648082412369fa65285e35e8487e08f5db696c",
#       "processToken": null,
#       "processed": false,
#       "published": null,
#       "s3Object": null,
#       "size": 35909,
#       "title": "",
#       "uploadedBy": "rmcclees-funinan@usgs.gov",
#       "url": "https://www.sciencebase.gov/catalog/file/get/5f066e2682ce21d4c3f90237?f=__disk__63%2F64%2F80%2F63648082412369fa65285e35e8487e08f5db696c",
#       "useForPreview": false
#     }
#   ],
#   "hasChildren": false,
#   "id": "5f066e2682ce21d4c3f90237",
#   "link": {
#     "rel": "self",
#     "url": "https://www.sciencebase.gov/catalog/item/5f066e2682ce21d4c3f90237"
#   },
#   "maintenanceUpdateFrequency": "Not planned",
#   "parentId": "5eea81f182ce3bd58d8575ee",
#   "previewImage": {
#     "alternateImages": [
#       {
#         "from": "mapPreview",
#         "original": {
#           "height": 240,
#           "size": 166883,
#           "uri": "https://www.sciencebase.gov/catalog/file/get/5f066e2682ce21d4c3f90237?f=__disk__09%2Fec%2F78%2F09ec783c9580c7d8771df41f7d36f8f7c2e5d5e0",
#           "viewUri": "https://www.sciencebase.gov/catalog/file/get/5f066e2682ce21d4c3f90237?f=__disk__09%2Fec%2F78%2F09ec783c9580c7d8771df41f7d36f8f7c2e5d5e0&width=360&height=240",
#           "viewUrl": "https://www.sciencebase.gov/catalog/file/get/5f066e2682ce21d4c3f90237?deprecated=__use__viewUri__instead__&f=__disk__09%2Fec%2F78%2F09ec783c9580c7d8771df41f7d36f8f7c2e5d5e0&width=360&height=240",
#           "width": 360
#         },
#         "thumbnail": {
#           "height": 100,
#           "uri": "https://www.sciencebase.gov/catalog/file/get/5f066e2682ce21d4c3f90237?f=__disk__09%2Fec%2F78%2F09ec783c9580c7d8771df41f7d36f8f7c2e5d5e0&width=150&height=100",
#           "width": 150
#         }
#       }
#     ],
#     "from": "attachedFile",
#     "medium": {
#       "height": 416,
#       "uri": "https://www.sciencebase.gov/catalog/file/get/5f066e2682ce21d4c3f90237?f=__disk__27%2F8b%2F76%2F278b76bf8027e39931171178ca23cbd9329a123a&width=580&height=416",
#       "width": 580
#     },
#     "original": {
#       "height": 760,
#       "size": 255597,
#       "uri": "https://www.sciencebase.gov/catalog/file/get/5f066e2682ce21d4c3f90237?f=__disk__27%2F8b%2F76%2F278b76bf8027e39931171178ca23cbd9329a123a",
#       "viewUri": "https://www.sciencebase.gov/catalog/file/get/5f066e2682ce21d4c3f90237?f=__disk__27%2F8b%2F76%2F278b76bf8027e39931171178ca23cbd9329a123a&width=1059&height=760",
#       "viewUrl": "https://www.sciencebase.gov/catalog/file/get/5f066e2682ce21d4c3f90237?deprecated=__use__viewUri__instead__&f=__disk__27%2F8b%2F76%2F278b76bf8027e39931171178ca23cbd9329a123a&width=1059&height=760",
#       "width": 1059
#     },
#     "small": {
#       "height": 251,
#       "uri": "https://www.sciencebase.gov/catalog/file/get/5f066e2682ce21d4c3f90237?f=__disk__27%2F8b%2F76%2F278b76bf8027e39931171178ca23cbd9329a123a&width=350&height=251",
#       "width": 350
#     },
#     "thumbnail": {
#       "height": 108,
#       "uri": "https://www.sciencebase.gov/catalog/file/get/5f066e2682ce21d4c3f90237?f=__disk__27%2F8b%2F76%2F278b76bf8027e39931171178ca23cbd9329a123a&width=150&height=108",
#       "width": 150
#     }
#   },
#   "provenance": {
#     "createdBy": "pbrown@usgs.gov",
#     "dataSource": "Input directly",
#     "dateCreated": "2020-07-09T01:08:54Z",
#     "lastUpdated": "2020-09-29T19:09:07Z",
#     "lastUpdatedBy": "rmcclees-funinan@usgs.gov"
#   },
#   "purpose": "The magnetic survey was flown as a component of U.S. Geological Survey (USGS) projects to improve the geologic framework for research related to mineral resource, energy resource, and geologic hazards studies in the area. Results from the survey will aid in providing insight into the magnetic signatures of exposed and concealed geology.",
#   "relatedItems": {
#     "link": {
#       "rel": "related",
#       "url": "https://www.sciencebase.gov/catalog/itemLinks?itemId=5f066e2682ce21d4c3f90237"
#     }
#   },
#   "spatial": {
#     "boundingBox": {
#       "maxX": -91.318886,
#       "maxY": 36.500267,
#       "minX": -93.825821,
#       "minY": 35.513279
#     }
#   },
#   "subTitle": "Airborne magnetic and radiometric survey over northwest Arkansas, 2019-2020",
#   "summary": "This publication provides digital flight line data for a high-resolution magnetic survey over an area of northwest Arkansas. The airborne geophysical survey was jointly funded by the USGS National Cooperative Geologic Mapping Program and the Earth Mapping Resource Initiative and was designed to meet the complimentary needs related to geologic mapping and mineral resource research. The survey covers an irregular area 225 by 110 kilometers over the transition between the Ouachita and Ozarks Plateau physiographic provinces and includes 67,614 line-kilometers of magnetic data. Data were collected from a fixed-wing aircraft flown at mean terrain clearance of 167 meters above topography along N-S flight lines spaced at 200 meter intervals. [...]",
#   "systemTypes": [
#     "Downloadable",
#     "Mappable"
#   ],
#   "tags": [
#     {
#       "name": "magnetic field (earth)",
#       "scheme": "USGS Thesaurus",
#       "type": "Theme"
#     },
#     {
#       "name": "geophysics",
#       "scheme": "USGS Thesaurus",
#       "type": "Theme"
#     },
#     {
#       "name": "geospatial datasets",
#       "scheme": "USGS Thesaurus",
#       "type": "Theme"
#     },
#     {
#       "name": "aeromagnetic surveying",
#       "scheme": "USGS Thesaurus",
#       "type": "Theme"
#     },
#     {
#       "name": "aeroradiometric surveying",
#       "scheme": "USGS Thesaurus",
#       "type": "Theme"
#     },
#     {
#       "name": "potassium",
#       "scheme": "USGS Thesaurus",
#       "type": "Theme"
#     },
#     {
#       "name": "uranium",
#       "scheme": "USGS Thesaurus",
#       "type": "Theme"
#     },
#     {
#       "name": "thorium",
#       "scheme": "USGS Thesaurus",
#       "type": "Theme"
#     },
#     {
#       "name": "radon",
#       "scheme": "USGS Thesaurus",
#       "type": "Theme"
#     },
#     {
#       "name": "geoscientificInformation",
#       "scheme": "ISO 19115 Topic Category",
#       "type": "Theme"
#     },
#     {
#       "name": "economy",
#       "scheme": "ISO 19115 Topic Category",
#       "type": "Theme"
#     },
#     {
#       "name": "Mineral Resources Program",
#       "scheme": "None",
#       "type": "Theme"
#     },
#     {
#       "name": "MRP",
#       "scheme": "None",
#       "type": "Theme"
#     },
#     {
#       "name": "Geology, Geophysics, and Geochemistry Science Center",
#       "scheme": "None",
#       "type": "Theme"
#     },
#     {
#       "name": "GGGSC",
#       "scheme": "None",
#       "type": "Theme"
#     },
#     {
#       "name": "Earth Mapping Resources Initiative",
#       "scheme": "None",
#       "type": "Theme"
#     },
#     {
#       "name": "EarthMRI",
#       "scheme": "None",
#       "type": "Theme"
#     },
#     {
#       "name": "horizontal magnetic gradiometry",
#       "scheme": "None",
#       "type": "Theme"
#     },
#     {
#       "name": "vertical magnetic gradient",
#       "scheme": "None",
#       "type": "Theme"
#     },
#     {
#       "name": "airborne geophysical survey",
#       "scheme": "None",
#       "type": "Theme"
#     },
#     {
#       "name": "U.S. Geological Survey",
#       "scheme": "None",
#       "type": "Theme"
#     },
#     {
#       "name": "USGS",
#       "scheme": "None",
#       "type": "Theme"
#     },
#     {
#       "name": "Association of American State Geologists",
#       "scheme": "None",
#       "type": "Theme"
#     },
#     {
#       "name": "AASG",
#       "scheme": "None",
#       "type": "Theme"
#     },
#     {
#       "name": "EON Geosciences, Inc.",
#       "scheme": "None",
#       "type": "Theme"
#     },
#     {
#       "name": "Rn",
#       "scheme": "None",
#       "type": "Theme"
#     },
#     {
#       "name": "Boston Mountains",
#       "scheme": "USGS Geographic Names Information System (GNIS), https://geonames.usgs.gov",
#       "type": "Place"
#     },
#     {
#       "name": "Carroll County",
#       "scheme": "USGS Geographic Names Information System (GNIS), https://geonames.usgs.gov",
#       "type": "Place"
#     },
#     {
#       "name": "Madison County",
#       "scheme": "USGS Geographic Names Information System (GNIS), https://geonames.usgs.gov",
#       "type": "Place"
#     },
#     {
#       "name": "Franklin County",
#       "scheme": "USGS Geographic Names Information System (GNIS), https://geonames.usgs.gov",
#       "type": "Place"
#     },
#     {
#       "name": "Johnson County",
#       "scheme": "USGS Geographic Names Information System (GNIS), https://geonames.usgs.gov",
#       "type": "Place"
#     },
#     {
#       "name": "Pope County",
#       "scheme": "USGS Geographic Names Information System (GNIS), https://geonames.usgs.gov",
#       "type": "Place"
#     },
#     {
#       "name": "Newton County",
#       "scheme": "USGS Geographic Names Information System (GNIS), https://geonames.usgs.gov",
#       "type": "Place"
#     },
#     {
#       "name": "Boone County",
#       "scheme": "USGS Geographic Names Information System (GNIS), https://geonames.usgs.gov",
#       "type": "Place"
#     },
#     {
#       "name": "Marion County",
#       "scheme": "USGS Geographic Names Information System (GNIS), https://geonames.usgs.gov",
#       "type": "Place"
#     },
#     {
#       "name": "Baxter County",
#       "scheme": "USGS Geographic Names Information System (GNIS), https://geonames.usgs.gov",
#       "type": "Place"
#     },
#     {
#       "name": "Stone County",
#       "scheme": "USGS Geographic Names Information System (GNIS), https://geonames.usgs.gov",
#       "type": "Place"
#     },
#     {
#       "name": "Izard County",
#       "scheme": "USGS Geographic Names Information System (GNIS), https://geonames.usgs.gov",
#       "type": "Place"
#     },
#     {
#       "name": "Sharp County",
#       "scheme": "USGS Geographic Names Information System (GNIS), https://geonames.usgs.gov",
#       "type": "Place"
#     },
#     {
#       "name": "Independence County",
#       "scheme": "USGS Geographic Names Information System (GNIS), https://geonames.usgs.gov",
#       "type": "Place"
#     },
#     {
#       "name": "Lawrence County",
#       "scheme": "USGS Geographic Names Information System (GNIS), https://geonames.usgs.gov",
#       "type": "Place"
#     },
#     {
#       "name": "Searcy County",
#       "scheme": "USGS Geographic Names Information System (GNIS), https://geonames.usgs.gov",
#       "type": "Place"
#     },
#     {
#       "name": "Washington County",
#       "scheme": "USGS Geographic Names Information System (GNIS), https://geonames.usgs.gov",
#       "type": "Place"
#     },
#     {
#       "name": "Van Buren County",
#       "scheme": "USGS Geographic Names Information System (GNIS), https://geonames.usgs.gov",
#       "type": "Place"
#     },
#     {
#       "name": "Barry County",
#       "scheme": "USGS Geographic Names Information System (GNIS), https://geonames.usgs.gov",
#       "type": "Place"
#     },
#     {
#       "name": "Arkansas",
#       "scheme": "Common geographic areas",
#       "type": "Place"
#     },
#     {
#       "name": "United States",
#       "scheme": "Common geographic areas",
#       "type": "Place"
#     },
#     {
#       "name": "USA",
#       "scheme": "None",
#       "type": "Place"
#     },
#     {
#       "name": "United States of America",
#       "scheme": "None",
#       "type": "Place"
#     },
#     {
#       "name": "Ouachita Plateau",
#       "scheme": "None",
#       "type": "Place"
#     },
#     {
#       "name": "Ozarks Plateau",
#       "scheme": "None",
#       "type": "Place"
#     }
#   ],
#   "title": "Airborne magnetic and radiometric survey over northwest Arkansas, 2019-2020; Magnetic Data"
# }

# %%
#Get the names of the file items in ScienceBase:
#print(item_json['files'])

print ('Items listed on ScienceBase page and corresponding URL according to ScienceBase Query:\n')
for item in item_json['files']:
    print (item['name'])
    print (item['downloadUri']+'\n')
# Out:
# Items listed on ScienceBase page according to ScienceBase Query:
#
# USA_Northwest-Arkansas-Airborne-Survey-2019-2020_MagneticData.csv
# https://www.sciencebase.gov/catalog/file/get/5f066e2682ce21d4c3f90237?f=__disk__cc%2F4b%2F74%2Fcc4b74b648e130ab6b71b1801f918b4e14e8ff03
#
# USA_Northwest-Arkansas-Airborne-Survey-2019-2020_Raster_TMFIShaded.png
# https://www.sciencebase.gov/catalog/file/get/5f066e2682ce21d4c3f90237?f=__disk__27%2F8b%2F76%2F278b76bf8027e39931171178ca23cbd9329a123a
#
# USA_Northwest-Arkansas-Airborne-Survey-2019-2020_Magnetic.xml
# https://www.sciencebase.gov/catalog/file/get/5f066e2682ce21d4c3f90237?f=__disk__63%2F64%2F80%2F63648082412369fa65285e35e8487e08f5db696c

# %%
# Compare this to the metadata Entity and Atribute item
print ('Items reported in Entity and Attribute section of metadata:\n')
print ('*** Entity and Attributes ***\n==============================\n')
for enttyp in root.iter('enttyp'):
 enttypl = enttyp.find('enttypl')
 print ('\t' + enttypl.text)
print ('\n*** Overview ***\n=================\n') 
for overview in root.iter('overview'):
 eaover = overview.find('eaover')
 print ('\t' + eaover.text)
 eadetcit = overview.find('eadetcit')
 print ('\t' + eadetcit.text)
# Out:
# Items reported in Entity and Attribute section of metadata:
#
# *** Entity and Attributes ***
# ==============================
#
# 	USA_Northwest-Arkansas-Airborne-Survey-2019-2020_MagneticData.csv
# 	USA_Northwest-Arkansas-Airborne-Survey-2019-2020_GeoreferencedRaster_ShadedTMF.tif
# 	USA_Northwest-Arkansas-Airborne-Survey-2019-2020_GeoreferencedRaster_ShadedTMFI.tif
# 	USA_Northwest-Arkansas-Airborne-Survey-2019-2020_GeoreferencedRaster_TMFI.tif
# 	USA_Northwest-Arkansas-Airborne-Survey-2019-2020_GeoreferencedRaster_VerticalMagneticGradientShaded.tif
#
# *** Overview ***
# =================
#
# 	USA_Northwest-Arkansas-Airborne-Survey-2019-2020_Raster_TMFIShaded.png is a Portable Network Graphics (PNG) image of the Total Magnetic Field Intensity with shading.
# 	https://doi.org/10.5066/P91O2Y8W

# %% [markdown]
# > - **Add Comments Here**

# %% [markdown]
# ##### b.	Links to data, publications, and services exist (although links may change when final DOI is assigned);

# %%
#Find all links in metdata and print out to check
#Note that this terminates the string listing at the first space after http - this isn't the end of the link
#As a result there are generally too many characters printed in the link - select corect part of URL and check
#manually in the web browser
#Find all links in metdata and print out to check
import re
print ('All text in metadata with http in the string and terminated by a space or other user selected character:\n')
linkLoc = [m.start() for m in re.finditer('http', metaData)]
#print (linkLoc)
for i in range(len(linkLoc)):
 indexSpace = metaData.find(' ',linkLoc[i])#user selected character is whatever is in between single quotes on this line of script.
 print ('indexSpace = ' + str(indexSpace))
 linkURL = metaData[linkLoc[i]:indexSpace]
 print (linkURL +'\n')
# Out:
# All text in metadata with http in the string and terminated by a space or other user selected character:
#
# indexSpace = 759
# https://orcid.org/0000-0001-5574-9201;
#
# indexSpace = 814
# http://orcid.org/0000-0002-2415-7462.
#
# indexSpace = 1041
# https://doi.org/10.5066/P91O2Y8W.</othercit>
#
#
#
# indexSpace = 1109
# https://doi.org/10.5066/P91O2Y8W</onlink>
#
#
#
# indexSpace = 2962
# https://doi.org/10.3133/fs20193007.
#
# indexSpace = 6371
# https://geonames.usgs.gov</placekt>
#
#
#
# indexSpace = 40329
# https://doi.org/10.5066/P91O2Y8W</eadetcit>
#
#
#
# indexSpace = 41243
# https://www.sciencebase.gov/catalog/item/5f066e2682ce21d4c3f90237</resdesc>
#
#
#
# indexSpace = 42768
# https://www.sciencebase.gov/catalog/item/requestDownload/5f066e2682ce21d4c3f90237?filePath=__disk__cc%2F4b%2F74%2Fcc4b74b648e130ab6b71b1801f918b4e14e8ff03</networkr>
#
#
#
# indexSpace = 43795
# https://www.sciencebase.gov/catalog/file/get/5f066e2682ce21d4c3f90237?f=__disk__27%2F8b%2F76%2F278b76bf8027e39931171178ca23cbd9329a123a</networkr>

# %%
#remind user of catalog number
print('Catalog number being assessed: ' + catNum)
# Out:
# Catalog number being assessed: 5f066e2682ce21d4c3f90237

# %% [markdown]
# ***
# ###  <center><span style="color:red">!!! **Add Comments Here** !!!</span></center>
# ***
# > Comments Include:

# %% [markdown]
# ##### c.	Metadata explains field names and values contained in the dataset. Data tables, fields, and values must be explained clearly so that a non-specialist can understand them; verify that entity and attribute content of metadata (detailed section or data dictionary) corresponds to data set;

# %%
#Get the names of the file items in ScienceBase:
#print(item_json['files'])

for item in item_json['files']:
    print (item['name'])
    print (item['downloadUri']+'\n')
# Out:
# USA_Northwest-Arkansas-Airborne-Survey-2019-2020_MagneticData.csv
# https://www.sciencebase.gov/catalog/file/get/5f066e2682ce21d4c3f90237?f=__disk__cc%2F4b%2F74%2Fcc4b74b648e130ab6b71b1801f918b4e14e8ff03
#
# USA_Northwest-Arkansas-Airborne-Survey-2019-2020_Raster_TMFIShaded.png
# https://www.sciencebase.gov/catalog/file/get/5f066e2682ce21d4c3f90237?f=__disk__27%2F8b%2F76%2F278b76bf8027e39931171178ca23cbd9329a123a
#
# USA_Northwest-Arkansas-Airborne-Survey-2019-2020_Magnetic.xml
# https://www.sciencebase.gov/catalog/file/get/5f066e2682ce21d4c3f90237?f=__disk__63%2F64%2F80%2F63648082412369fa65285e35e8487e08f5db696c

# %%
#Let's see if we can read a csv into pandas
#Get URL from the list printed above
csvDataURL = "https://www.sciencebase.gov/catalog/file/get/5f066e2682ce21d4c3f90237?f=__disk__cc%2F4b%2F74%2Fcc4b74b648e130ab6b71b1801f918b4e14e8ff03"
csvDataFrame = pd.read_csv(csvDataURL, sep=',', delimiter=None, header='infer', names=None, index_col=None, usecols=None, squeeze=False, prefix=None, mangle_dupe_cols=True, dtype=None, engine=None, converters=None, true_values=None, false_values=None, skipinitialspace=False, skiprows=None, nrows=None, na_values=None, keep_default_na=True, na_filter=True, verbose=False, skip_blank_lines=True, parse_dates=True, infer_datetime_format=True, keep_date_col=False, date_parser=None, dayfirst=False, iterator=False, chunksize=None, compression='infer', thousands=None, decimal=b'.', lineterminator=None, quotechar='"', quoting=0, doublequote=True, escapechar=None, comment=None, encoding=None, dialect=None, error_bad_lines=True, warn_bad_lines=True, delim_whitespace=False, low_memory=True, memory_map=False, float_precision=None)
#csvDataFrame.head()
csvDataFrame
# Out:
#              baltl      baltlc       barom         baseB        baseBo  \
# 0       434.727020  434.463745  434.463745  50849.468750  50849.460938
# 1       434.630951  434.388794  434.388794  50849.468750  50849.460938
# 2       434.534912  434.313812  434.313812  50849.468750  50849.464844
# 3       434.438843  434.238861  434.238861  50849.468750  50849.468750
# 4       434.342804  434.163879  434.163879  50849.468750  50849.468750
# 5       434.246735  434.088928  434.088928  50849.468750  50849.468750
# 6       434.150665  434.013977  434.013977  50849.468750  50849.472656
# 7       434.054626  433.938995  433.938995  50849.468750  50849.476562
# 8       433.958557  433.864044  433.864044  50849.468750  50849.476562
# 9       433.862518  433.789062  433.789062  50849.468750  50849.476562
# 10      433.766449  433.714111  433.714111  50849.468750  50849.480469
# 11      433.642212  433.615845  433.615845  50849.468750  50849.480469
# 12      433.517944  433.517578  433.517578  50849.468750  50849.476562
# 13      433.393677  433.419312  433.419312  50849.468750  50849.476562
# 14      433.269440  433.321045  433.321045  50849.468750  50849.476562
# 15      433.145203  433.222778  433.222778  50849.468750  50849.476562
# 16      433.020935  433.124542  433.124542  50849.468750  50849.472656
# 17      432.896698  433.026276  433.026276  50849.468750  50849.472656
# 18      432.772430  432.928009  432.928009  50849.468750  50849.472656
# 19      432.648163  432.829742  432.829742  50849.468750  50849.468750
# 20      432.523926  432.731476  432.731476  50849.468750  50849.468750
# 21      432.426025  432.599915  432.599915  50849.468750  50849.464844
# 22      432.328125  432.468384  432.468384  50849.468750  50849.464844
# 23      432.230194  432.336823  432.336823  50849.468750  50849.460938
# 24      432.132294  432.205261  432.205261  50849.468750  50849.457031
# 25      432.034393  432.073730  432.073730  50849.468750  50849.453125
# 26      431.936493  431.942169  431.942169  50849.468750  50849.453125
# 27      431.838593  431.810608  431.810608  50849.468750  50849.449219
# 28      431.740662  431.679047  431.679047  50849.468750  50849.445312
# 29      431.642761  431.547516  431.547516  50849.468750  50849.445312
# ...            ...         ...         ...           ...           ...
# 971011  430.588409  432.438477  432.438477  50838.070312  50837.984375
# 971012  430.425903  432.227905  432.227905  50838.070312  50837.980469
# 971013  430.263367  432.017334  432.017334  50838.070312  50837.976562
# 971014  430.100861  431.806732  431.806732  50838.070312  50837.976562
# 971015  429.938354  431.596161  431.596161  50838.070312  50837.976562
# 971016  429.775848  431.385559  431.385559  50838.070312  50837.972656
# 971017  429.613342  431.174988  431.174988  50838.070312  50837.968750
# 971018  429.450836  430.964386  430.964386  50838.070312  50837.968750
# 971019  429.740265  430.922089  430.922089  50838.070312  50837.968750
# 971020  430.029694  430.879761  430.879761  50838.066406  50837.968750
# 971021  430.319122  430.837463  430.837463  50838.066406  50837.968750
# 971022  430.608551  430.795166  430.795166  50838.066406  50837.968750
# 971023  430.897980  430.752869  430.752869  50838.062500  50837.968750
# 971024  431.187408  430.710541  430.710541  50838.062500  50837.968750
# 971025  431.476837  430.668243  430.668243  50838.062500  50837.968750
# 971026  431.766266  430.625946  430.625946  50838.062500  50837.968750
# 971027  432.055695  430.583618  430.583618  50838.058594  50837.968750
# 971028  432.345123  430.541321  430.541321  50838.058594  50837.968750
# 971029  432.409973  430.634399  430.634399  50838.058594  50837.964844
# 971030  432.474823  430.727478  430.727478  50838.058594  50837.964844
# 971031  432.539642  430.820526  430.820526  50838.054688  50837.960938
# 971032  432.604492  430.913605  430.913605  50838.054688  50837.957031
# 971033  432.669342  431.006683  431.006683  50838.054688  50837.953125
# 971034  432.734192  431.099762  431.099762  50838.054688  50837.953125
# 971035  432.799042  431.192841  431.192841  50838.054688  50837.949219
# 971036  432.863861  431.285889  431.285889  50838.050781  50837.945312
# 971037  432.928711  431.378967  431.378967  50838.050781  50837.945312
# 971038  432.993561  431.472046  431.472046  50838.050781  50837.941406
# 971039  432.929626  431.622650  431.622650  50838.050781  50837.941406
# 971040  432.865723         NaN         NaN           NaN           NaN
#
#               date  directn       drape        DTMc        DTMo     ...      \
# 0       2019/11/01    180.0  561.883484  453.275665  450.339722     ...
# 1       2019/11/01    180.0  561.773315  452.800385  449.706970     ...
# 2       2019/11/01    180.0  561.663208  452.325073  449.074219     ...
# 3       2019/11/01    180.0  561.553040  451.849762  448.441498     ...
# 4       2019/11/01    180.0  561.442932  451.374481  447.808746     ...
# 5       2019/11/01    180.0  561.332764  450.899170  447.175995     ...
# 6       2019/11/01    180.0  561.222595  450.423889  446.543243     ...
# 7       2019/11/01    180.0  561.112488  449.948608  445.910492     ...
# 8       2019/11/01    180.0  561.002319  449.473297  445.277771     ...
# 9       2019/11/01    180.0  560.892212  448.997986  444.645020     ...
# 10      2019/11/01    180.0  560.782043  448.522705  444.012268     ...
# 11      2019/11/01    180.0  560.674316  448.147583  443.696167     ...
# 12      2019/11/01    180.0  560.566650  447.772491  443.380035     ...
# 13      2019/11/01    180.0  560.458923  447.397369  443.063934     ...
# 14      2019/11/01    180.0  560.351196  447.022278  442.747803     ...
# 15      2019/11/01    180.0  560.243530  446.647156  442.431702     ...
# 16      2019/11/01    180.0  560.135803  446.272034  442.115601     ...
# 17      2019/11/01    180.0  560.028076  445.896942  441.799469     ...
# 18      2019/11/01    180.0  559.920349  445.521820  441.483368     ...
# 19      2019/11/01    180.0  559.812683  445.146729  441.167236     ...
# 20      2019/11/01    180.0  559.704956  444.771606  440.851135     ...
# 21      2019/11/01    180.0  559.599365  445.139526  441.435760     ...
# 22      2019/11/01    180.0  559.493774  445.507446  442.020416     ...
# 23      2019/11/01    180.0  559.388184  445.875397  442.605042     ...
# 24      2019/11/01    180.0  559.282593  446.243317  443.189697     ...
# 25      2019/11/01    180.0  559.177002  446.611237  443.774323     ...
# 26      2019/11/01    180.0  559.071350  446.979156  444.358948     ...
# 27      2019/11/01    180.0  558.965759  447.347076  444.943604     ...
# 28      2019/11/01    180.0  558.860168  447.715027  445.528229     ...
# 29      2019/11/01    180.0  558.754578  448.082947  446.112885     ...
# ...            ...      ...         ...         ...         ...     ...
# 971011  2019/11/05    180.0  550.206360  389.452209  385.082642     ...
# 971012  2019/11/05    180.0  550.143250  390.302856  385.895752     ...
# 971013  2019/11/05    180.0  550.080139  391.153503  386.708893     ...
# 971014  2019/11/05    180.0  550.017029  392.004150  387.522034     ...
# 971015  2019/11/05    180.0  549.953918  392.854797  388.335144     ...
# 971016  2019/11/05    180.0  549.890747  393.705444  389.148285     ...
# 971017  2019/11/05    180.0  549.827637  394.556091  389.961395     ...
# 971018  2019/11/05    180.0  549.764526  395.406738  390.774536     ...
# 971019  2019/11/05    180.0  549.705505  395.082703  390.432800     ...
# 971020  2019/11/05    180.0  549.646423  394.758667  390.091034     ...
# 971021  2019/11/05    180.0  549.587402  394.434662  389.749298     ...
# 971022  2019/11/05    180.0  549.528320  394.110626  389.407562     ...
# 971023  2019/11/05    180.0  549.469299  393.786591  389.065796     ...
# 971024  2019/11/05    180.0  549.410278  393.462555  388.724060     ...
# 971025  2019/11/05    180.0  549.351196  393.138519  388.382324     ...
# 971026  2019/11/05    180.0  549.292175  392.814514  388.040588     ...
# 971027  2019/11/05    180.0  549.233093  392.490479  387.698822     ...
# 971028  2019/11/05    180.0  549.174072  392.166443  387.357086     ...
# 971029  2019/11/05    180.0  549.119080  391.383301  386.545441     ...
# 971030  2019/11/05    180.0  549.064087  390.600128  385.733765     ...
# 971031  2019/11/05    180.0  549.009094  389.816986  384.922119     ...
# 971032  2019/11/05    180.0  548.954102  389.033813  384.110443     ...
# 971033  2019/11/05    180.0  548.899048  388.250671  383.298798     ...
# 971034  2019/11/05    180.0  548.844055  387.467529  382.487152     ...
# 971035  2019/11/05    180.0  548.789062  386.684357  381.675476     ...
# 971036  2019/11/05    180.0  548.734070  385.901215  380.863831     ...
# 971037  2019/11/05    180.0  548.679077  385.118042  380.052155     ...
# 971038  2019/11/05    180.0  548.624084  384.334900  379.240509     ...
# 971039  2019/11/05    180.0  548.573059  383.407593  378.348328     ...
# 971040         NaN      NaN         NaN         NaN         NaN     ...
#
#              raltl      raltlc      resmag    topoSRTM        totmag  \
# 0       115.773071  112.837120   47.682865  457.549774  50667.148438
# 1       115.987556  113.068268   47.768021  456.893555  50667.195312
# 2       115.573914  113.343529   47.857082  456.237305  50667.246094
# 3       116.830132  113.683571   47.950050  455.581055  50667.300781
# 4       116.447144  114.088440   48.046921  454.924835  50667.359375
# 5       117.059937  114.536728   48.143795  454.268616  50667.417969
# 6       116.722893  114.999191   48.244576  453.612366  50667.480469
# 7       117.841248  115.455612   48.345356  452.956146  50667.542969
# 8       118.699158  115.901619   48.446136  452.299896  50667.605469
# 9       120.277107  116.342010   48.543007  451.643646  50667.664062
# 10      121.288208  116.777763   48.639881  450.987427  50667.722656
# 11      122.054199  117.198112   48.728893  450.954956  50667.773438
# 12      120.767334  117.585884   48.817905  450.922485  50667.824219
# 13      121.410774  117.934792   48.903011  450.890045  50667.871094
# 14      122.804878  118.263840   48.995930  450.857574  50667.925781
# 15      123.478951  118.608559   49.084942  450.825104  50667.976562
# 16      123.325752  118.985619   49.177860  450.792633  50668.031250
# 17      123.509583  119.356346   49.270779  450.760162  50668.085938
# 18      123.371712  119.626480   49.375416  450.727722  50668.152344
# 19      123.279778  119.693924   49.476147  450.695251  50668.214844
# 20      123.432976  119.512505   49.576878  450.662781  50668.277344
# 21      123.739372  119.120529   49.676979  450.460114  50668.339844
# 22      123.861938  118.611740   49.777081  450.257446  50668.402344
# 23      123.049988  118.075943   49.881088  450.054779  50668.468750
# 24      121.104378  117.557671   49.981190  449.852112  50668.531250
# 25      119.710274  117.057144   50.089108  449.649475  50668.601562
# 26      118.576607  116.557739   50.204834  449.446808  50668.679688
# 27      117.504211  116.049553   50.320560  449.244141  50668.757812
# 28      117.335701  115.534622   50.444099  449.041473  50668.843750
# 29      116.968025  115.019890   50.575451  448.838806  50668.937500
# ...            ...         ...         ...         ...           ...
# 971011  161.102081  155.922699 -129.597717  386.081299  50473.628906
# 971012  161.002930  154.425583 -129.393097  386.412567  50473.792969
# 971013  158.125427  152.896988 -129.184570  386.743835  50473.960938
# 971014  156.637146  151.533844 -128.983871  387.075134  50474.121094
# 971015  155.446426  150.587830 -128.790970  387.406403  50474.273438
# 971016  154.950363  150.212631 -128.601974  387.737671  50474.421875
# 971017  155.644928  150.359680 -128.432526  388.068939  50474.550781
# 971018  155.446426  150.814224 -128.274780  388.400208  50474.667969
# 971019  156.736313  151.339005 -128.140564  388.504791  50474.761719
# 971020  157.629364  151.804138 -128.021957  388.609375  50474.839844
# 971021  155.744095  152.205139 -127.915085  388.713959  50474.906250
# 971022  155.644928  152.585617 -127.823830  388.818542  50474.957031
# 971023  156.240234  152.968643 -127.752106  388.923157  50474.988281
# 971024  158.522339  153.355148 -127.699913  389.027740  50475.000000
# 971025  158.919235  153.749878 -127.663345  389.132324  50474.996094
# 971026  159.712967  154.152985 -127.630692  389.236908  50474.988281
# 971027  159.514557  154.526688 -127.609749  389.341492  50474.968750
# 971028  159.613800  154.804443 -127.592712  389.446075  50474.945312
# 971029  158.423096  154.967972 -127.579674  389.069916  50474.917969
# 971030  158.819992  155.117905 -127.570541  388.693756  50474.886719
# 971031  160.010696  155.440491 -127.569221  388.317627  50474.847656
# 971032  160.903671  156.077087 -127.567902  387.941467  50474.808594
# 971033  162.491211  157.011749 -127.574394  387.565308  50474.761719
# 971034  161.895889  158.094193 -127.584793  387.189148  50474.710938
# 971035  162.292801  159.182510 -127.595192  386.812988  50474.660156
# 971036  164.872559  160.263672 -127.605591  386.436859  50474.609375
# 971037  166.261673  161.429382 -127.615990  386.060699  50474.558594
# 971038  167.849213  162.754807 -127.626389  385.684540  50474.507812
# 971039  169.734406  164.233475 -127.640770  385.072632  50474.453125
# 971040         NaN         NaN         NaN         NaN           NaN
#
#                 um3l             x           y    year           z
# 0       50681.457031  426297.15625  4012245.75  2019.0  568.612793
# 1       50681.480469  426297.03125  4012238.25  2019.0  568.531555
# 2       50681.507812  426296.90625  4012230.75  2019.0  568.450317
# 3       50681.539062  426296.75000  4012223.25  2019.0  568.369080
# 4       50681.574219  426296.62500  4012215.75  2019.0  568.287842
# 5       50681.617188  426296.50000  4012208.00  2019.0  568.206665
# 6       50681.667969  426296.37500  4012200.50  2019.0  568.125427
# 7       50681.722656  426296.25000  4012193.00  2019.0  568.044189
# 8       50681.785156  426296.09375  4012185.50  2019.0  567.962952
# 9       50681.851562  426295.96875  4012178.00  2019.0  567.881714
# 10      50681.914062  426295.84375  4012170.50  2019.0  567.800476
# 11      50681.976562  426295.78125  4012163.00  2019.0  567.698853
# 12      50682.039062  426295.71875  4012155.50  2019.0  567.597229
# 13      50682.101562  426295.65625  4012147.75  2019.0  567.495544
# 14      50682.160156  426295.59375  4012140.25  2019.0  567.393921
# 15      50682.218750  426295.50000  4012132.75  2019.0  567.292297
# 16      50682.277344  426295.43750  4012125.25  2019.0  567.190674
# 17      50682.339844  426295.37500  4012117.75  2019.0  567.089050
# 18      50682.402344  426295.31250  4012110.00  2019.0  566.987366
# 19      50682.464844  426295.25000  4012102.50  2019.0  566.885742
# 20      50682.531250  426295.18750  4012095.00  2019.0  566.784119
# 21      50682.593750  426295.12500  4012087.50  2019.0  566.651794
# 22      50682.660156  426295.06250  4012080.00  2019.0  566.519470
# 23      50682.730469  426295.00000  4012072.50  2019.0  566.387146
# 24      50682.796875  426294.93750  4012065.00  2019.0  566.254822
# 25      50682.867188  426294.87500  4012057.50  2019.0  566.122437
# 26      50682.937500  426294.81250  4012049.75  2019.0  565.990112
# 27      50683.011719  426294.75000  4012042.25  2019.0  565.857788
# 28      50683.093750  426294.68750  4012034.75  2019.0  565.725464
# 29      50683.175781  426294.62500  4012027.25  2019.0  565.593140
# ...              ...           ...         ...     ...         ...
# 971011  50476.589844  443899.40625  4008235.75  2019.0  549.210632
# 971012  50476.781250  443899.28125  4008227.75  2019.0  549.140686
# 971013  50476.968750  443899.18750  4008219.50  2019.0  549.070679
# 971014  50477.144531  443899.06250  4008211.50  2019.0  549.000732
# 971015  50477.304688  443898.93750  4008203.50  2019.0  548.930786
# 971016  50477.445312  443898.81250  4008195.50  2019.0  548.860840
# 971017  50477.574219  443898.68750  4008187.25  2019.0  548.790894
# 971018  50477.679688  443898.56250  4008179.25  2019.0  548.720947
# 971019  50477.769531  443898.50000  4008171.25  2019.0  548.795959
# 971020  50477.839844  443898.46875  4008163.00  2019.0  548.870911
# 971021  50477.894531  443898.40625  4008155.00  2019.0  548.945923
# 971022  50477.945312  443898.34375  4008147.00  2019.0  549.020935
# 971023  50477.976562  443898.31250  4008139.00  2019.0  549.095947
# 971024  50477.996094  443898.25000  4008130.75  2019.0  549.170898
# 971025  50477.996094  443898.18750  4008122.75  2019.0  549.245911
# 971026  50477.988281  443898.12500  4008114.75  2019.0  549.320923
# 971027  50477.968750  443898.09375  4008106.50  2019.0  549.395874
# 971028  50477.933594  443898.03125  4008098.50  2019.0  549.470886
# 971029  50477.886719  443898.12500  4008090.50  2019.0  549.482788
# 971030  50477.824219  443898.21875  4008082.25  2019.0  549.494629
# 971031  50477.753906  443898.28125  4008074.25  2019.0  549.506531
# 971032  50477.679688  443898.37500  4008066.00  2019.0  549.518433
# 971033  50477.597656  443898.46875  4008058.00  2019.0  549.530273
# 971034  50477.511719  443898.56250  4008050.00  2019.0  549.542175
# 971035  50477.437500  443898.65625  4008041.75  2019.0  549.554077
# 971036  50477.363281  443898.71875  4008033.75  2019.0  549.565979
# 971037  50477.296875  443898.81250  4008025.50  2019.0  549.577820
# 971038  50477.230469  443898.90625  4008017.50  2019.0  549.589722
# 971039  50477.160156  443898.93750  4008009.50  2019.0  549.650085
# 971040           NaN           NaN         NaN     NaN         NaN
#
# [971041 rows x 42 columns]

# %%
# now get an array of the header names and print them out.
csvHeaderList = list(csvDataFrame.columns.values)
sortedCsvHeaderList = sorted(csvHeaderList)

for i in range(len(csvHeaderList)):
 print (str(i) + ',' + csvHeaderList[i])

#for i in range(len(sortedCsvHeaderList)):
 #print (str(i) + ',' + sortedCsvHeaderList[i])
# Out:
# 0,baltl
# 1,baltlc
# 2,barom
# 3,baseB
# 4,baseBo
# 5,date
# 6,directn
# 7,drape
# 8,DTMc
# 9,DTMo
# 10,fid10
# 11,fiducial
# 12,flt
# 13,hgps
# 14,jul_day
# 15,lat
# 16,latitude
# 17,line
# 18,line_no
# 19,lon
# 20,longitud
# 21,m3l
# 22,mfluxX
# 23,mfluxY
# 24,mfluxZ
# 25,mreslc
# 26,mreslcb
# 27,mreslct
# 28,mreslvl
# 29,mreslvld
# 30,mreslvldi
# 31,radar
# 32,raltl
# 33,raltlc
# 34,resmag
# 35,topoSRTM
# 36,totmag
# 37,um3l
# 38,x
# 39,y
# 40,year
# 41,z

# %% [markdown]
# > - **Add Comments Here**

# %%
#Creat Min and Max Arrays
#Calculate Min Max and print result:
csvMax = []
csvMin = []

#Loop through arrays and callculate values
for i in range (4): #(len(csvHeaderList)): #This isn't working for the date value for some reason - want to get min/max
 print (csvHeaderList[i] + ': ' + str(i))
 strCol = csvHeaderList[i]
 csvMax.append(csvDataFrame[strCol].max())
 csvMin.append(csvDataFrame[strCol].min())
 print ('Max. Value ' + csvHeaderList[i] + ' :' + str(csvMax[i]))
 print ('Min. Value ' + csvHeaderList[i] + ' :' + str(csvMin[i]))
# Out:
# baltl: 0
# Max. Value baltl :817.537719726563
# Min. Value baltl :187.180862426758
# baltlc: 1
# Max. Value baltlc :815.8208618164059
# Min. Value baltlc :186.960800170898
# barom: 2
# Max. Value barom :815.8208618164059
# Min. Value barom :186.960800170898
# baseB: 3
# Max. Value baseB :50856.87890625
# Min. Value baseB :50823.08984375

# %%
# Compare this to the metadata Entity and Atribute item
print ('*** Entity and Attributes ***\n==============================\n')
i = 0
for enttyp in root.iter('attr'):
 attrlabl = enttyp.find('attrlabl')
 attrdef = enttyp.find('attrdef')
 attrlablMeta = attrlabl.text
 attrdefMeta = attrdef.text
 if i < len(csvHeaderList):
    print ('CSV file value: ' + csvHeaderList[i])
    if csvHeaderList[i] != attrlabl.text:
     print ('!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!VALUES DON"T MATCH!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!')
 print ('Metadata file value: ' + attrlabl.text +  '\nDefinition: ' + attrdef.text + '\n')
 i = i + 1
    
#for i in range(len(attrlablMeta)):
 #print (attrlablMeta[i])
# Out:
# *** Entity and Attributes ***
# ==============================
#
# CSV file value: baltl
# Metadata file value: baltl
# Definition: Baro altitude, raw. MSL, computed from measured pressure and temperature
#
# CSV file value: baltlc
# Metadata file value: baltlc
# Definition: Baro altitude, edited. MSL, low-pass filtered against noise and spikes
#
# CSV file value: barom
# Metadata file value: barom
# Definition: Barometric altitude above MSL. Same as [baltlc]
#
# CSV file value: baseB
# Metadata file value: baseB
# Definition: Main mag base, edited. Edited against cultural signal and noise
#
# CSV file value: baseBo
# Metadata file value: baseBo
# Definition: Main mag base, raw	Raw main mag base station
#
# CSV file value: date
# Metadata file value: date
# Definition: Acquisition date. Start of acquisition, UTC
#
# CSV file value: directn
# Metadata file value: directn
# Definition: Flight line direction, azimuth degrees from north.
#
# CSV file value: drape
# Metadata file value: drape
# Definition: Drape altitude. MSL, planned flight surface for navigation
#
# CSV file value: DTMc
# Metadata file value: DTMc
# Definition: Digital terrain model. MSL, DTM model, [z-2.5m-raltlc], GPS ant. 2.5m above radar ant.
#
# CSV file value: DTMo
# Metadata file value: DTMo
# Definition: Digital terrain model. MSL, DTM model, [z-2.5m-raltl], GPS ant. 2.5m above radar ant.
#
# CSV file value: fid10
# Metadata file value: fid10
# Definition: Fiducial, Oasis. RMS system fiducial
#
# CSV file value: fiducial
# Metadata file value: fiducial
# Definition: Fiducial number, same as [fid10] (10Hz version)
#
# CSV file value: flt
# Metadata file value: flt
# Definition: Flight number
#
# CSV file value: hgps
# Metadata file value: hgps
# Definition: hgps
#
# CSV file value: jul_day
# Metadata file value: jul_day
# Definition: Julian day flown.
#
# CSV file value: lat
# Metadata file value: lat
# Definition: Latitude, decimal degrees.
#
# CSV file value: latitude
# Metadata file value: latitude
# Definition: Latitude, decimal degrees, same as [lat].
#
# CSV file value: line
# Metadata file value: line
# Definition: Line number, edited lll: planned line number, n: segment code.
#
# CSV file value: line_no
# Metadata file value: line_no
# Definition: Flight line number, same as [line].
#
# CSV file value: lon
# Metadata file value: lon
# Definition: Longitude decimal degrees.
#
# CSV file value: longitud
# Metadata file value: longitud
# Definition: Decimal degrees, same as [lon].
#
# CSV file value: m3l
# Metadata file value: m3l
# Definition: Compensated TMF, raw. Sensor 3, tail stinger.
#
# CSV file value: mfluxX
# Metadata file value: mfluxX
# Definition: Fluxgate MF-X, raw. Longitudinal vector fluxgate sensor.
#
# CSV file value: mfluxY
# Metadata file value: mfluxY
# Definition: Fluxgate MF-Y, raw. Transverse vector fluxgate sensor.
#
# CSV file value: mfluxZ
# Metadata file value: mfluxZ
# Definition: Fluxgate MF-Z, raw. Vertical vector fluxgate ensor.
#
# CSV file value: mreslc
# Metadata file value: mreslc
# Definition: TMF, partial IGRF removed. Partial IGRF to drape surface removed from m3l.
#
# CSV file value: mreslcb
# Metadata file value: mreslcb
# Definition: TMF, diurnals corrected. Filtered (LP 7500m) and zero-average diurnals removed from mreslc
#
# CSV file value: mreslct
# Metadata file value: mreslct
# Definition: TMF, Taylor signal removed. Taylor-corrected for drape deviations
#
# CSV file value: mreslvl
# Metadata file value: mreslvl
# Definition: TMF, levelled. Intersection levelling of mreslcb
#
# CSV file value: mreslvld
# Metadata file value: mreslvld
# Definition: TMF, micro-levelled Micro-levelling correction applied on mreslct.
#
# CSV file value: mreslvldi
# Metadata file value: mreslvldi
# Definition: IGRF residual of TMF. Using 2015 model with fixed date, 2020-01-01 and altitude 549.89m.
#
# CSV file value: radar
# Metadata file value: radar
# Definition: Radar altitude above ground, Same as [raltlc], 10Hz version.
#
# CSV file value: raltl
# Metadata file value: raltl
# Definition: Radar altitude, raw. AGL, linear transformation from raw readings.
#
# CSV file value: raltlc
# Metadata file value: raltlc
# Definition: Radar altitude, edited. AGL, low-pass filtered against noise, spikes and jumps.
#
# CSV file value: resmag
# Metadata file value: resmag
# Definition: CResidual magnetic value. Same as [mreslvldi].
#
# CSV file value: topoSRTM
# Metadata file value: topoSRTM
# Definition: Published terrain model MSL, DTM model from SRTM grid.
#
# CSV file value: totmag
# Metadata file value: totmag
# Definition: Corrected TMF value. Same as [mreslvld].
#
# CSV file value: um3l
# Metadata file value: um3l
# Definition: Uncompensated TMF, raw. Sensor 3, tail stinger.
#
# CSV file value: x
# Metadata file value: x
# Definition: UTM Easting WGS-84, Z15N, differential PP-DGPS.
#
# CSV file value: y
# Metadata file value: y
# Definition: UTM Northing WGS-84, Z15N, differential PP-DGPS.
#
# CSV file value: year
# Metadata file value: year
# Definition: year
#
# CSV file value: z
# Metadata file value: z
# Definition: GPS altitude, unedited MSL, differential PP-DGPS.
#
# Metadata file value: Value
# Definition: Unique numeric values contained in each raster cell.
#
# Metadata file value: Value
# Definition: Unique numeric values contained in each raster cell.
#
# Metadata file value: Value
# Definition: Unique numeric values contained in each raster cell.
#
# Metadata file value: Value
# Definition: Unique numeric values contained in each raster cell.

# %% [markdown]
# >  **Add Comments Here**

# %% [markdown]
# ###### d.	If applicable, geographic coordinates are provided, and they match location keywords in metadata and also agree with the data;

# %%
# Get the bounding coordinates from the metadata
# Compare this to the metadata Entity and Atribute item
for bounding in root.iter('bounding'):
 westbc = bounding.find('westbc')
 print ('westbc: ' + westbc.text)
 eastbc = bounding.find('eastbc')
 print ('eastbc: ' + eastbc.text)
 northbc = bounding.find('northbc')
 print ('northbc: ' + northbc.text)
 southbc = bounding.find('southbc')
 print ('southbc: ' + southbc.text)
# Out:
# westbc: -91.318886
# eastbc: -93.825821
# northbc: 36.500267
# southbc: 35.513279

# %%
# Get the bounding box coordinates from the ScienceBase catalog entry and from the  metadata and compare:
#i = 0
#for enttyp in root.iter('attr'):
 #attrlabl = enttyp.find('attrlabl')
 #attrdef = enttyp.find('attrdef')
 #attrlablMeta = attrlabl.text

# %% [markdown]
# > - **Add Coordinates here.**

# %% [markdown]
# ##### e.	Keywords accurately represent the data and include terms from standard vocabularies whenever possible (such as the USGS Thesaurus, http://www.usgs.gov/science/services.html or  the Biocomplexity Thesaurus, http://www.usgs.gov/core_science_systems/csas/biocomplexity_thesaurus

# %%
#Load Theme Keywords
print ('*** Theme Keywords ***\n======================')
for theme in root.iter('theme'):
 themekt = theme.find('themekt')
 print ("\t*** " + themekt.text + " ***\n\t------------------------------------------------------------------------------")
 for themekey in theme.findall('themekey'):
        print('\t\t' + themekey.text)
# Out:
# *** Theme Keywords ***
# =======================
# 	*** USGS Thesaurus ***
# 	------------------------------------------------------------------------------
# 		magnetic field (earth)
# 		geophysics
# 		geospatial datasets
# 		aeromagnetic surveying
# 		aeroradiometric surveying
# 		potassium
# 		uranium
# 		thorium
# 		radon
# 	*** ISO 19115 Topic Category ***
# 	------------------------------------------------------------------------------
# 		geoscientificInformation
# 		economy
# 	*** None ***
# 	------------------------------------------------------------------------------
# 		Mineral Resources Program
# 		MRP
# 		Geology, Geophysics, and Geochemistry Science Center
# 		GGGSC
# 		Earth Mapping Resources Initiative
# 		EarthMRI
# 		horizontal magnetic gradiometry
# 		vertical magnetic gradient
# 		airborne geophysical survey
# 		U.S. Geological Survey
# 		USGS
# 		Association of American State Geologists
# 		AASG
# 		EON Geosciences, Inc.
# 		Rn
# 	*** USGS Metadata Identifier ***
# 	------------------------------------------------------------------------------
# 		USGS:5f066e2682ce21d4c3f90237

# %%
#Load Place Keywords
print ('*** PLACE KEYWORDS ***\n======================')
for place in root.iter('place'):
 placekt = place.find('placekt')
 print ("\t*** " + placekt.text + " ***\n\t------------------------------------------------------------------------------")
 for placekey in place.findall('placekey'):
        print('\t\t' + placekey.text)
# Out:
# *** PLACE KEYWORDS ***
# ======================
# 	*** USGS Geographic Names Information System (GNIS), https://geonames.usgs.gov ***
# 	------------------------------------------------------------------------------
# 		Boston Mountains
# 		Carroll County
# 		Madison County
# 		Franklin County
# 		Johnson County
# 		Pope County
# 		Newton County
# 		Boone County
# 		Marion County
# 		Baxter County
# 		Stone County
# 		Izard County
# 		Sharp County
# 		Independence County
# 		Lawrence County
# 		Searcy County
# 		Washington County
# 		Johnson County
# 		Van Buren County
# 		Barry County
# 	*** Common geographic areas ***
# 	------------------------------------------------------------------------------
# 		Arkansas
# 		United States
# 	*** None ***
# 	------------------------------------------------------------------------------
# 		USA
# 		United States of America
# 		Ouachita Plateau
# 		Ozarks Plateau

# %% [markdown]
# <script>mendeleyWebImporter = { open: function () { window.postMessage('0.7247748277875938', 'null') } }</script></body>
# <h3 style="color: #006633;">Secondary validation results</h3>
# <table class="table table-condensed table-bordered">
#   <thead>
#     <tr>
#       <th scope="col">Test</th>
#       <th scope="col">Result</th>
#       <th scope="col">Report</th>
#     </tr>
#   </thead>
#   <tbody style="font-size: small;">
#     <tr>
#       <td>ISO 19115 Topic Category</td>
#       <td style="background-color: #99ff99;">Success</td>
#       <td style="white-space: pre;">All 2 keywords are valid</td>
#     </tr>
#     <tr>
#       <td>USGS Thesaurus</td>
#       <td style="background-color: #99ff99;">Success</td>
#       <td style="white-space: pre;">All 9 keywords are valid</td>
#     </tr>

# %% [markdown]
# > - **Add keywords comments here**

# %% [markdown]
# ##### f. Information about data processing steps, methodology, and lineage are included in the record and match any associated publications. Could a scientist or technician recreate the final data set from the descriptions? Can documentation about methodology be easily found and used? Are processing software and versions identified, if applicable?;

# %%
#Load process steps
for procstep in root.iter('procstep'):
 procdate = procstep.find('procdate')
 print ('*** PROCDATE ***\n' + procdate.text)
 procdesc = procstep.find('procdesc')
 print ('*** PROCSTEP ***\n' + procdesc.text + '\n\n')
# Out:
# *** PROCDATE ***
# 20191005
# *** PROCSTEP ***
# The airborne survey was flown under contract to the U.S. Geological Survey by EON Geosciences Inc., from October 5, 2019 to March 7, 2020. The magnetic data were acquired with a Geometrics G-822A cesium-vapour split-beam sensor. The radiometric data were acquired with a Radiation Solutions RS-500 series multi-channel gamma-ray spectrometers, models RSX-5 and RSX-4, with 1,024 channels, for a total volume of 33.6 liters downward-looking and 8.4 liters (C-FEON) or 4.2 liters (C-GPTB) upward-looking crystals (for measuring effects of atmospheric radon). Data were collected along east-west flight lines spaced 200 meters (m) apart with north-south tie lines flown every 3,000 meters. A mean terrain clearance of 80 m was maintained except where safety dictated a higher elevation. A total of 66,477 line-kilometers of data were collected.
#
#
# *** PROCDATE ***
# 20200316
# *** PROCSTEP ***
# Preliminary magnetic and radiometric data processing was undertaken by EON Geosciences, Inc. of Montreal, Quebec, Canada. This processing workflow is described in the contractors report included with this data release.
#
#
# *** PROCDATE ***
# 20200629
# *** PROCSTEP ***
# Final data and contractors report were accepted and received by USGS from EON Geosciences, Inc.
#
#
# *** PROCDATE ***
# 20200707
# *** PROCSTEP ***
# Created georeferenced rasters of the data grids provided by the contractor.  Created Esri shapefiles of area footprint and line paths for the survey using the line data provided by the contractor.
#
#
# *** PROCDATE ***
# 20200707
# *** PROCSTEP ***
# Final data were exported to CSV-format to meet open data requirements.

# %% [markdown]
# > - **Add process step comments here**

# %% [markdown]
# ##### g. The metadata provides complete and current information about how to use the data files – access instructions, unusual software requirements, data models, definitions of terms, size of the data, etc;

# %% [markdown]
# > - **Add special information comments here**

# %% [markdown]
# ###### h.	The data quality section adequately describes the procedures used to ensure the quality of the data;

# %%
#Load data quality items
for attracc in root.iter('attracc'):
 attraccr = attracc.find('attraccr')
 print ('*** ATTRACCR ***\n ' + attraccr.text)
for dataqual in root.iter('dataqual'):
 logic = dataqual.find('logic')
 print ('\n*** LOGIC ***\n ' + logic.text)
for dataqual in root.iter('dataqual'):
 complete = dataqual.find('complete')
 print ('\n*** COMPLETE ***\n' + complete.text)
for horizpa in root.iter('horizpa'):
 horizpar = horizpa.find('horizpar')
 print ('\n*** HORIZPAR ***\n ' + horizpar.text)
for vertacc in root.iter('vertacc'):
 vertaccr = vertacc.find('vertaccr')
 print ('\n*** VERTACCR ***\n' + vertaccr.text )
# Out:
# *** ATTRACCR ***
#  Daily quality control of raw radiometric and magnetic data was performed by the contractor. Further quality control measures occurred post flight by the contractor and USGS scientist-in-charge before approval and acceptance of the final data. The data have been peer reviewed and compared with related ancillary data.
#
# *** LOGIC ***
#  Data were visually inspected for reasonableness and spatial consistency.
#
# *** COMPLETE ***
# Data set is considered complete for the information presented, as described in the abstract. Users are advised to read the rest of the metadata record carefully for additional details.
#
# *** HORIZPAR ***
#  Field quality control and assurance procedures were undertaken by the Eon Geosciences Inc. field crew and are described in the contractors report included with this data release.
#
# *** VERTACCR ***
# Field quality control and assurance procedures were undertaken by the Eon Geosciences Inc. field crew and are described in the contractors report included with this data release.

# %% [markdown]
# > **Data quality section comments here.**

# %% [markdown]
# ###### i.	Access constraints, use constraints, and distribution liability statements are included and are consistent with USGS policy:
# - desired accconst:<br>
# None. Please see 'Distribution Info' for details.
#
#
# - desired useconst:<br>
# Any use of trade, firm, or product names is for descriptive purposes only and does not imply endorsement by the U.S. Government.  Although these data have been processed successfully on a computer system at the U.S. Geological Survey (USGS), no warranty expressed or implied is made regarding the display or utility of the data for other purposes, nor on all computer systems, nor shall the act of distribution constitute any such warranty. The USGS or the U.S. Government shall not be held liable for improper or incorrect use of the data described and/or contained herein.
#
#
# - desired distliab:<br>
# Unless otherwise stated, all data, metadata and related materials are considered to satisfy the quality standards relative to the purpose for which the data were collected. Although these data and associated metadata have been reviewed for accuracy and completeness and approved for release by the U.S. Geological Survey (USGS), no warranty expressed or implied is made regarding the display or utility of the data for other purposes, nor on all computer systems, nor shall the act of distribution constitute any such warranty.

# %%
# Load liability statements to check against above text
for idinfo in root.iter('idinfo'):
 accconst = idinfo.find('accconst')
 print ('*** ACCCONST ***\n' + accconst.text)
for idinfo in root.iter('idinfo'):
 useconst = idinfo.find('useconst')
 print ('\n*** USECONST ***\n' + useconst.text)
for distinfo in root.iter('distinfo'):
 distliab = distinfo.find('distliab')
 print ('\n*** DISTLIAB ***\n' + distliab.text)
# Out:
# *** ACCCONST ***
# None. Please see 'Distribution Info' for details.
#
# *** USECONST ***
# Any use of trade, firm, or product names is for descriptive purposes only and does not imply endorsement by the U.S. Government. Although these data have been processed successfully on a computer system at the U.S. Geological Survey (USGS), no warranty expressed or implied is made regarding the display or utility of the data for other purposes, nor on all computer systems, nor shall the act of distribution constitute any such warranty. The USGS or the U.S. Government shall not be held liable for improper or incorrect use of the data described and/or contained herein. Acknowledgment of the U.S. Geological Survey would be appreciated in products derived from these data.
#
# *** DISTLIAB ***
# Unless otherwise stated, all data, metadata and related materials are considered to satisfy the quality standards relative to the purpose for which the data were collected. Although these data and associated metadata have been reviewed for accuracy and completeness and approved for release by the U.S. Geological Survey (USGS), no warranty expressed or implied is made regarding the display or utility of the data on any other system or for general or scientific purposes, nor shall the act of distribution constitute any such warranty.

# %% [markdown]
# > - **Add liability statement comments here**

# %% [markdown]
# ##### j.	If the data or metadata have been revised, correct version identification is provided (see: https://www2.usgs.gov/fsp/data_versioning.asp);

# %% [markdown]
# ##### k.	Content is written in a way that is usable and helpful, without use of special formatting or characters that will fail to be transferred to XML (generally metadata should be encoded using UTF-8).**

# %% [markdown]
# > - **Add content comments here**
